# %%
import asyncio
from pantheon import pantheon

from utils import configuration

settings = configuration.settings
server = "na1"
api_key = settings.api_key


def requestsLog(url, status, headers):
    print(url)
    print(status)
    print(headers)


panth = pantheon.Pantheon(
    server, api_key, requests_logging_function=requestsLog, debug=True)


async def getSummonerId(name):
    try:
        data = await panth.get_tft_summoner_by_name(name)
        return (data['id'], data['accountId'], data['puuid'])
    except Exception as e:
        print(e)


async def getRecentMatchlist(accountId):
    try:
        data = await panth.get_matchlist(accountId, params={"count":2})
        print(f'data: {data}')
        return data
    except Exception as e:
        print(e)


async def getRecentMatches(accountId):
    try:
        matchlist = await getRecentMatchlist(accountId)
        tasks = [panth.get_match(match)
                 for match in matchlist]
        return await asyncio.gather(*tasks)
    except Exception as e:
        print(e)

async def getTFTRecentMatchlist(accountId):
    try:
        data = await panth.get_tft_matchlist(accountId, count = 2)
        print(f'data: {data}')
        return data
    except Exception as e:
        print(e)


async def getTFTRecentMatches(accountId):
    try:
        matchlist = await getTFTRecentMatchlist(accountId)
        tasks = [panth.get_tft_match(match)
                 for match in matchlist]
        return await asyncio.gather(*tasks)
    except Exception as e:
        print(e)

# %%
name = "fury hawkx"

loop = asyncio.get_event_loop()

# %%
(id, summonerId, accountId) = await getSummonerId(name)
# (id, summonerId, accountId) = asyncio.run_coroutine_threadsafe(getSummonerId(name), loop)
# Out:
# https://na1.api.riotgames.com/tft/summoner/v1/summoners/by-name/fury hawkx
# 200
# <CIMultiDictProxy('Date': 'Thu, 21 Jul 2022 01:49:57 GMT', 'Content-Type': 'application/json;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'X-App-Rate-Limit': '20:1,100:120', 'X-App-Rate-Limit-Count': '1:1,1:120', 'X-Method-Rate-Limit': '2000:60', 'X-Method-Rate-Limit-Count': '1:60', 'X-Riot-Edge-Trace-Id': '3696970a-9af7-4348-8d38-d8776a004bb6', 'Content-Encoding': 'gzip', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, PUT, DELETE, POST, OPTIONS', 'Access-Control-Allow-Headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range', 'Access-Control-Expose-Headers': 'Content-Length,Content-Range')>

# %%
print(f'summonerId: {summonerId}')
# Out:
# summonerId: Oy6TkFdjvE1A5FtEkHMa-QJbkOXOWCvaXGbHOFDnlsZZdjg

# %%
print(f'accountId: {accountId}')
# Out:
# accountId: pPy5MdXKClKsVTrAFWj2k8tatNIWovBTghWRjyjfbEQRDNYVD5Cfj4hkEaYdEB7khH1J6oQ7QtKPLg

# %%
lol_tasks = await getTFTRecentMatches(accountId)
# Out:
# https://americas.api.riotgames.com/tft/match/v1/matches/by-puuid/pPy5MdXKClKsVTrAFWj2k8tatNIWovBTghWRjyjfbEQRDNYVD5Cfj4hkEaYdEB7khH1J6oQ7QtKPLg/ids?count=2
# 200
# <CIMultiDictProxy('Date': 'Thu, 21 Jul 2022 01:54:02 GMT', 'Content-Type': 'application/json;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'X-App-Rate-Limit': '20:1,100:120', 'X-App-Rate-Limit-Count': '1:1,4:120', 'X-Method-Rate-Limit': '400:10', 'X-Method-Rate-Limit-Count': '1:10', 'X-Riot-Edge-Trace-Id': 'a2127355-4917-4f16-a9aa-e6b6fa8123ea', 'Content-Encoding': 'gzip', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, PUT, DELETE, POST, OPTIONS', 'Access-Control-Allow-Headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range', 'Access-Control-Expose-Headers': 'Content-Length,Content-Range')>
# data: ['NA1_4379006381', 'NA1_4378413824']
# https://americas.api.riotgames.com/tft/match/v1/matches/NA1_4379006381
# 200
# <CIMultiDictProxy('Date': 'Thu, 21 Jul 2022 01:54:03 GMT', 'Content-Type': 'application/json;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'X-App-Rate-Limit': '20:1,100:120', 'X-App-Rate-Limit-Count': '2:1,5:120', 'X-Method-Rate-Limit': '200:10', 'X-Method-Rate-Limit-Count': '1:10', 'X-Riot-Edge-Trace-Id': '0e05761c-eabd-4fd8-bd39-bfb67e101be6', 'Content-Encoding': 'gzip', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, PUT, DELETE, POST, OPTIONS', 'Access-Control-Allow-Headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range', 'Access-Control-Expose-Headers': 'Content-Length,Content-Range')>
# https://americas.api.riotgames.com/tft/match/v1/matches/NA1_4378413824
# 200
# <CIMultiDictProxy('Date': 'Thu, 21 Jul 2022 01:54:03 GMT', 'Content-Type': 'application/json;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'X-App-Rate-Limit': '20:1,100:120', 'X-App-Rate-Limit-Count': '3:1,6:120', 'X-Method-Rate-Limit': '200:10', 'X-Method-Rate-Limit-Count': '2:10', 'X-Riot-Edge-Trace-Id': 'b67eb209-b8b6-411d-8fac-8d97f5d8e6ec', 'Content-Encoding': 'gzip', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, PUT, DELETE, POST, OPTIONS', 'Access-Control-Allow-Headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range', 'Access-Control-Expose-Headers': 'Content-Length,Content-Range')>

# %%
lol_tasks[0] #['metadata'] #['info']['participants'][0]['perks'] #['metadata']
# Out:
# {'metadata': {'data_version': '5',
#   'match_id': 'NA1_4379006381',
#   'participants': ['FSEAeloEaL4kf4eau2xefjxO3xjbbr0AfbHVAGMhfNRUUeAG5rcV9wuR2KKFvXyYwsMfDQmYpYqXCw',
#    'ZNCqjCYDCaSRCdoudTeQHLNUHcoc1PkEhED1jfmCyHegQjYfg5gqm4J2JPFMvveDWq5WN9tlZ-3LhQ',
#    'M-8X7VAadU_fmtndK-V1zxFFAcIRKF4QTLJr83kiXrCFMkPHPg1rz7rLmzE6Auyb4-G50q590A6S7w',
#    'wdtsCObSOruL1f9px4PN2ynDPxLote22FjtfootpHs6nL6qHS6wo3Ok9qCybluRDoEdqmd4fwct-_w',
#    'pPy5MdXKClKsVTrAFWj2k8tatNIWovBTghWRjyjfbEQRDNYVD5Cfj4hkEaYdEB7khH1J6oQ7QtKPLg',
#    'KCq1VZg7fYxSEjT6KztFEEKys_FgfcEdUlnoJe_2N1daqqKo_HGsU6IWdsgMZ2AyXPlctZKuNCqmTA',
#    'OsQA7o8LPtClUXRAOdvHadilUP9E_k6oAl7bfqQv_gCwaOAbCEqTa28DxODXfaETyMI2yqNUD-P8kw',
#    'Ir-0m0U3Hd3ACBnbPe_qPgz20wAIap5d-9sQWwUOlhmwsc3IyErN5oZkLNPgDMaxRvsTpyfjr1QMpQ']},
#  'info': {'game_datetime': 1658283530844,
#   'game_length': 2199.414794921875,
#   'game_version': 'Version 12.13.453.3037 (Jul 11 2022/18:39:20) [PUBLIC] <Releases/12.13>',
#   'participants': [{'augments': ['TFT7_Augment_GuildEmblem',
#      'TFT6_Augment_SecondWind2',
#      'TFT6_Augment_Diversify2'],
#     'companion': {'content_ID': 'b890d4df-181a-43da-861d-99a72afbc602',
#      'skin_ID': 2,
#      'species': 'PetChibiYasuo'},
#     'gold_left': 2,
#     'last_round': 26,
#     'level': 8,
#     'placement': 8,
#     'players_eliminated': 0,
#     'puuid': 'FSEAeloEaL4kf4eau2xefjxO3xjbbr0AfbHVAGMhfNRUUeAG5rcV9wuR2KKFvXyYwsMfDQmYpYqXCw',
#     'time_eliminated': 1613.69580078125,
#     'total_damage_to_players': 72,
#     'traits': [{'name': 'Set7_Assassin',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Cavalier',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Dragon',
#       'num_units': 1,
#       'style': 3,
#       'tier_current': 1,
#       'tier_total': 2},
#      {'name': 'Set7_Dragonmancer',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Guardian',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Guild',
#       'num_units': 4,
#       'style': 2,
#       'tier_current': 4,
#       'tier_total': 7},
#      {'name': 'Set7_Ragewing',
#       'num_units': 3,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3},
#      {'name': 'Set7_Shapeshifter',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Shimmerscale',
#       'num_units': 3,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Swiftshot',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3}],
#     'units': [{'character_id': 'TFT7_Sejuani',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 0,
#       'tier': 2},
#      {'character_id': 'TFT7_Twitch',
#       'itemNames': ['TFT_Item_StatikkShiv', 'TFT_Item_ZekesHerald'],
#       'items': [24, 17],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Swain',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 2,
#       'tier': 1},
#      {'character_id': 'TFT7_Hecarim',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 3,
#       'tier': 1},
#      {'character_id': 'TFT7_Talon',
#       'itemNames': ['TFT_Item_HextechGunblade'],
#       'items': [13],
#       'name': '',
#       'rarity': 3,
#       'tier': 1},
#      {'character_id': 'TFT7_Xayah',
#       'itemNames': ['TFT7_Item_GuildEmblemItem',
#        'TFT_Item_GuinsoosRageblade',
#        'TFT_Item_MadredsBloodrazor'],
#       'items': [2318, 23, 12],
#       'name': '',
#       'rarity': 3,
#       'tier': 1},
#      {'character_id': 'TFT7_DragonGold',
#       'itemNames': ['TFT7_Item_ShimmerscaleMogulsMail',
#        'TFT_Item_WarmogsArmor',
#        'TFT_Item_RedBuff'],
#       'items': [3000, 77, 57],
#       'name': '',
#       'rarity': 4,
#       'tier': 2}]},
#    {'augments': ['TFT6_Augment_TargetDummies',
#      'TFT6_Augment_CelestialBlessing2',
#      'TFT7_Augment_UrfsGrabBag1'],
#     'companion': {'content_ID': '3f358b24-6ca3-4943-85b1-8fb1981e93be',
#      'skin_ID': 16,
#      'species': 'PetChoncc'},
#     'gold_left': 5,
#     'last_round': 27,
#     'level': 7,
#     'placement': 6,
#     'players_eliminated': 0,
#     'puuid': 'ZNCqjCYDCaSRCdoudTeQHLNUHcoc1PkEhED1jfmCyHegQjYfg5gqm4J2JPFMvveDWq5WN9tlZ-3LhQ',
#     'time_eliminated': 1714.032470703125,
#     'total_damage_to_players': 55,
#     'traits': [{'name': 'Set7_Astral',
#       'num_units': 6,
#       'style': 2,
#       'tier_current': 2,
#       'tier_total': 3},
#      {'name': 'Set7_Bruiser',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Guild',
#       'num_units': 1,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 7},
#      {'name': 'Set7_Mage',
#       'num_units': 3,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Mystic',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4},
#      {'name': 'Set7_Shapeshifter',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3},
#      {'name': 'Set7_Swiftshot',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3},
#      {'name': 'Set7_Whispers',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4}],
#     'units': [{'character_id': 'TFT7_Vladimir',
#       'itemNames': [],
#       'items': [],
#       'name': 'Vladimir',
#       'rarity': 0,
#       'tier': 3},
#      {'character_id': 'TFT7_Skarner',
#       'itemNames': ['TFT_Item_ForceOfNature'],
#       'items': [88],
#       'name': 'Skarner',
#       'rarity': 0,
#       'tier': 3},
#      {'character_id': 'TFT7_Nidalee',
#       'itemNames': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_Bloodthirster'],
#       'items': [23, 16],
#       'name': 'Nidalee',
#       'rarity': 0,
#       'tier': 3},
#      {'character_id': 'TFT7_Nami',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 1,
#       'tier': 3},
#      {'character_id': 'TFT7_Twitch',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Elise',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 2,
#       'tier': 1},
#      {'character_id': 'TFT7_Varus',
#       'itemNames': ['TFT_Item_LastWhisper',
#        'TFT_Item_Bloodthirster',
#        'TFT_Item_GuinsoosRageblade'],
#       'items': [29, 16, 23],
#       'name': '',
#       'rarity': 2,
#       'tier': 3},
#      {'character_id': 'TFT7_Illaoi',
#       'itemNames': ['TFT7_Item_MageEmblemItem', 'TFT_Item_RedBuff'],
#       'items': [2311, 57],
#       'name': '',
#       'rarity': 2,
#       'tier': 2}]},
#    {'augments': ['TFT7_Augment_BruiserEmblem',
#      'TFT6_Augment_SecondWind2',
#      'TFT6_Augment_CyberneticUplink2'],
#     'companion': {'content_ID': 'b890d4df-181a-43da-861d-99a72afbc602',
#      'skin_ID': 2,
#      'species': 'PetChibiYasuo'},
#     'gold_left': 10,
#     'last_round': 33,
#     'level': 9,
#     'placement': 4,
#     'players_eliminated': 1,
#     'puuid': 'M-8X7VAadU_fmtndK-V1zxFFAcIRKF4QTLJr83kiXrCFMkPHPg1rz7rLmzE6Auyb4-G50q590A6S7w',
#     'time_eliminated': 2056.58251953125,
#     'total_damage_to_players': 95,
#     'traits': [{'name': 'Set7_Assassin',
#       'num_units': 4,
#       'style': 3,
#       'tier_current': 2,
#       'tier_total': 3},
#      {'name': 'Set7_Bruiser',
#       'num_units': 4,
#       'style': 2,
#       'tier_current': 2,
#       'tier_total': 4},
#      {'name': 'Set7_Dragon',
#       'num_units': 1,
#       'style': 3,
#       'tier_current': 1,
#       'tier_total': 2},
#      {'name': 'Set7_Guardian',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Guild',
#       'num_units': 1,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 7},
#      {'name': 'Set7_Legend',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 1},
#      {'name': 'Set7_Mage',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4},
#      {'name': 'Set7_Shapeshifter',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Tempest',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Whispers',
#       'num_units': 7,
#       'style': 3,
#       'tier_current': 3,
#       'tier_total': 4}],
#     'units': [{'character_id': 'TFT7_Thresh',
#       'itemNames': ['TFT7_Item_BruiserEmblemItem'],
#       'items': [2305],
#       'name': 'Thresh',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Qiyana',
#       'itemNames': ['TFT_Item_FrozenHeart', 'TFT_Item_GuinsoosRageblade'],
#       'items': [45, 23],
#       'name': '',
#       'rarity': 1,
#       'tier': 1},
#      {'character_id': 'TFT7_Elise',
#       'itemNames': ['TFT_Item_Zephyr'],
#       'items': [67],
#       'name': '',
#       'rarity': 2,
#       'tier': 2},
#      {'character_id': 'TFT7_Sylas',
#       'itemNames': ['TFT_Item_RedBuff'],
#       'items': [57],
#       'name': '',
#       'rarity': 2,
#       'tier': 2},
#      {'character_id': 'TFT7_Talon',
#       'itemNames': ['TFT_Item_BFSword'],
#       'items': [1],
#       'name': '',
#       'rarity': 3,
#       'tier': 1},
#      {'character_id': 'TFT7_DragonPurple',
#       'itemNames': ['TFT_Item_Bloodthirster',
#        'TFT_Item_TitansResolve',
#        'TFT7_Item_AssassinEmblemItem'],
#       'items': [16, 25, 2325],
#       'name': '',
#       'rarity': 4,
#       'tier': 2},
#      {'character_id': 'TFT7_Ornn',
#       'itemNames': ['TFT_Item_SpearOfShojin'],
#       'items': [14],
#       'name': '',
#       'rarity': 3,
#       'tier': 1},
#      {'character_id': 'TFT7_Pyke',
#       'itemNames': ['TFT_Item_WarmogsArmor'],
#       'items': [77],
#       'name': '',
#       'rarity': 5,
#       'tier': 1}]},
#    {'augments': ['TFT6_Augment_Electrocharge2',
#      'TFT7_Augment_GadgetExpert',
#      'TFT7_Augment_BestFriends2'],
#     'companion': {'content_ID': '85356c16-7748-4574-9ecc-13d79ccc3e5b',
#      'skin_ID': 20,
#      'species': 'PetBuglet'},
#     'gold_left': 8,
#     'last_round': 35,
#     'level': 9,
#     'placement': 1,
#     'players_eliminated': 2,
#     'puuid': 'wdtsCObSOruL1f9px4PN2ynDPxLote22FjtfootpHs6nL6qHS6wo3Ok9qCybluRDoEdqmd4fwct-_w',
#     'time_eliminated': 2191.193603515625,
#     'total_damage_to_players': 180,
#     'traits': [{'name': 'Set7_Assassin',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3},
#      {'name': 'Set7_Astral',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Bard',
#       'num_units': 1,
#       'style': 3,
#       'tier_current': 1,
#       'tier_total': 1},
#      {'name': 'Set7_Bruiser',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Dragon',
#       'num_units': 1,
#       'style': 3,
#       'tier_current': 1,
#       'tier_total': 2},
#      {'name': 'Set7_Guild',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 2,
#       'tier_total': 7},
#      {'name': 'Set7_Legend',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 1},
#      {'name': 'Set7_Mage',
#       'num_units': 3,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Mystic',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Shimmerscale',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4},
#      {'name': 'Set7_SpellThief',
#       'num_units': 1,
#       'style': 3,
#       'tier_current': 1,
#       'tier_total': 1},
#      {'name': 'Set7_Tempest',
#       'num_units': 5,
#       'style': 2,
#       'tier_current': 2,
#       'tier_total': 4},
#      {'name': 'Set7_Whispers',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4}],
#     'units': [{'character_id': 'TFT7_Nami',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Qiyana',
#       'itemNames': ['TFT_Item_IonicSpark'],
#       'items': [36],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Sylas',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 2,
#       'tier': 2},
#      {'character_id': 'TFT7_Talon',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 3,
#       'tier': 2},
#      {'character_id': 'TFT7_Ornn',
#       'itemNames': ['TFT_Item_Redemption', 'TFT_Item_IonicSpark'],
#       'items': [47, 36],
#       'name': '',
#       'rarity': 3,
#       'tier': 2},
#      {'character_id': 'TFT7_Zoe',
#       'itemNames': ['TFT_Item_Quicksilver',
#        'TFT_Item_StatikkShiv',
#        'TFT_Item_StatikkShiv'],
#       'items': [69, 24, 24],
#       'name': '',
#       'rarity': 5,
#       'tier': 1},
#      {'character_id': 'TFT7_Bard',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 5,
#       'tier': 1},
#      {'character_id': 'TFT7_AoShin',
#       'itemNames': ['TFT_Item_StatikkShiv',
#        'TFT_Item_HextechGunblade',
#        'TFT_Item_ArchangelsStaff'],
#       'items': [24, 13, 34],
#       'name': '',
#       'rarity': 6,
#       'tier': 2}]},
#    {'augments': ['TFT7_Augment_UrfsGrabBag1',
#      'TFT6_Augment_ThrillOfTheHunt2',
#      'TFT6_Augment_PortableForge'],
#     'companion': {'content_ID': 'd17f9a59-4ee6-4c41-9ba2-309dfb164885',
#      'skin_ID': 1,
#      'species': 'PetChibiYasuo'},
#     'gold_left': 4,
#     'last_round': 34,
#     'level': 8,
#     'placement': 3,
#     'players_eliminated': 2,
#     'puuid': 'pPy5MdXKClKsVTrAFWj2k8tatNIWovBTghWRjyjfbEQRDNYVD5Cfj4hkEaYdEB7khH1J6oQ7QtKPLg',
#     'time_eliminated': 2124.754150390625,
#     'total_damage_to_players': 94,
#     'traits': [{'name': 'Set7_Assassin',
#       'num_units': 4,
#       'style': 3,
#       'tier_current': 2,
#       'tier_total': 3},
#      {'name': 'Set7_Bruiser',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Dragon',
#       'num_units': 1,
#       'style': 3,
#       'tier_current': 1,
#       'tier_total': 2},
#      {'name': 'Set7_Guild',
#       'num_units': 1,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 7},
#      {'name': 'Set7_Jade',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4},
#      {'name': 'Set7_Legend',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 1},
#      {'name': 'Set7_Scalescorn',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Shapeshifter',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3},
#      {'name': 'Set7_Tempest',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Whispers',
#       'num_units': 4,
#       'style': 2,
#       'tier_current': 2,
#       'tier_total': 4}],
#     'units': [{'character_id': 'TFT7_Qiyana',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Elise',
#       'itemNames': ['TFT7_Item_AssassinEmblemItem',
#        'TFT_Item_InfinityEdge',
#        'TFT_Item_ArchangelsStaff'],
#       'items': [2325, 19, 34],
#       'name': '',
#       'rarity': 2,
#       'tier': 2},
#      {'character_id': 'TFT7_Diana',
#       'itemNames': ['TFT_Item_MadredsBloodrazor',
#        'TFT_Item_IonicSpark',
#        'TFT4_Item_OrnnZhonyasParadox'],
#       'items': [12, 36, 9010],
#       'name': '',
#       'rarity': 2,
#       'tier': 3},
#      {'character_id': 'TFT7_Talon',
#       'itemNames': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_Bloodthirster'],
#       'items': [12, 16],
#       'name': '',
#       'rarity': 3,
#       'tier': 2},
#      {'character_id': 'TFT7_Neeko',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 3,
#       'tier': 2},
#      {'character_id': 'TFT7_DragonPurple',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 4,
#       'tier': 2},
#      {'character_id': 'TFT7_Ornn',
#       'itemNames': ['TFT_Item_Zephyr',
#        'TFT_Item_WarmogsArmor',
#        'TFT_Item_GargoyleStoneplate'],
#       'items': [67, 77, 56],
#       'name': '',
#       'rarity': 3,
#       'tier': 2}]},
#    {'augments': ['TFT6_Augment_SecondWind2',
#      'TFT7_Augment_FirstAidKit2',
#      'TFT7_Augment_PandorasBench'],
#     'companion': {'content_ID': '06da6495-55da-43c7-ba7d-a7114018eefc',
#      'skin_ID': 19,
#      'species': 'PetGrumpyLion'},
#     'gold_left': 0,
#     'last_round': 35,
#     'level': 8,
#     'placement': 2,
#     'players_eliminated': 1,
#     'puuid': 'KCq1VZg7fYxSEjT6KztFEEKys_FgfcEdUlnoJe_2N1daqqKo_HGsU6IWdsgMZ2AyXPlctZKuNCqmTA',
#     'time_eliminated': 2191.193603515625,
#     'total_damage_to_players': 120,
#     'traits': [{'name': 'Set7_Bruiser',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4},
#      {'name': 'Set7_Dragonmancer',
#       'num_units': 6,
#       'style': 3,
#       'tier_current': 2,
#       'tier_total': 3},
#      {'name': 'Set7_Evoker',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Jade',
#       'num_units': 3,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Legend',
#       'num_units': 3,
#       'style': 3,
#       'tier_current': 1,
#       'tier_total': 1},
#      {'name': 'Set7_Mirage',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4},
#      {'name': 'Set7_Ragewing',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Shimmerscale',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4},
#      {'name': 'Set7_Swiftshot',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Tempest',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Warrior',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3}],
#     'units': [{'character_id': 'TFT7_Sett',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 0,
#       'tier': 2},
#      {'character_id': 'TFT7_Karma',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 0,
#       'tier': 2},
#      {'character_id': 'TFT7_Ashe',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_LeeSin',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 2,
#       'tier': 2},
#      {'character_id': 'TFT7_Volibear',
#       'itemNames': ['TFT_Item_GuinsoosRageblade',
#        'TFT_Item_Bloodthirster',
#        'TFT_Item_Quicksilver'],
#       'items': [23, 16, 69],
#       'name': '',
#       'rarity': 2,
#       'tier': 2},
#      {'character_id': 'TFT7_Anivia',
#       'itemNames': ['TFT_Item_SparringGloves'],
#       'items': [9],
#       'name': '',
#       'rarity': 2,
#       'tier': 2},
#      {'character_id': 'TFT7_Ornn',
#       'itemNames': ['TFT_Item_GargoyleStoneplate',
#        'TFT_Item_DragonsClaw',
#        'TFT_Item_IonicSpark'],
#       'items': [56, 66, 36],
#       'name': '',
#       'rarity': 3,
#       'tier': 2},
#      {'character_id': 'TFT7_Yasuo',
#       'itemNames': ['TFT_Item_FrozenHeart',
#        'TFT_Item_RedBuff',
#        'TFT_Item_GuardianAngel'],
#       'items': [45, 57, 94],
#       'name': '',
#       'rarity': 5,
#       'tier': 1}]},
#    {'augments': ['TFT7_Augment_MikaelsGift',
#      'TFT6_Augment_ComponentGrabBag',
#      'TFT6_Augment_Diversify2'],
#     'companion': {'content_ID': 'eb21cd43-7b67-4880-ae43-84a3e836057e',
#      'skin_ID': 19,
#      'species': 'PetFenroar'},
#     'gold_left': 0,
#     'last_round': 30,
#     'level': 8,
#     'placement': 5,
#     'players_eliminated': 0,
#     'puuid': 'OsQA7o8LPtClUXRAOdvHadilUP9E_k6oAl7bfqQv_gCwaOAbCEqTa28DxODXfaETyMI2yqNUD-P8kw',
#     'time_eliminated': 1885.76025390625,
#     'total_damage_to_players': 85,
#     'traits': [{'name': 'Set7_Assassin',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Cannoneer',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Dragon',
#       'num_units': 1,
#       'style': 3,
#       'tier_current': 1,
#       'tier_total': 2},
#      {'name': 'Set7_Evoker',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3},
#      {'name': 'Set7_Guardian',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3},
#      {'name': 'Set7_Guild',
#       'num_units': 1,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 7},
#      {'name': 'Set7_Mystic',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 4},
#      {'name': 'Set7_Revel',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Scalescorn',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Shimmerscale',
#       'num_units': 3,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4},
#      {'name': 'Set7_Trainer',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 2}],
#     'units': [{'character_id': 'TFT7_Tristana',
#       'itemNames': ['TFT_Item_ZekesHerald', 'TFT_Item_PowerGauntlet'],
#       'items': [17, 79],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Braum',
#       'itemNames': ['TFT_Item_RedBuff', 'TFT_Item_GargoyleStoneplate'],
#       'items': [57, 56],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Lulu',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 2,
#       'tier': 2},
#      {'character_id': 'TFT7_Corki',
#       'itemNames': ['TFT_Item_Deathblade',
#        'TFT_Item_InfinityEdge',
#        'TFT_Item_GuinsoosRageblade'],
#       'items': [11, 19, 23],
#       'name': '',
#       'rarity': 3,
#       'tier': 2},
#      {'character_id': 'TFT7_Talon',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 3,
#       'tier': 1},
#      {'character_id': 'TFT7_Sona',
#       'itemNames': ['TFT_Item_LocketOfTheIronSolari'],
#       'items': [35],
#       'name': '',
#       'rarity': 3,
#       'tier': 2},
#      {'character_id': 'TFT7_DragonGold',
#       'itemNames': ['TFT_Item_DragonsClaw',
#        'TFT7_Item_ShimmerscaleMogulsMail'],
#       'items': [66, 3000],
#       'name': '',
#       'rarity': 4,
#       'tier': 2},
#      {'character_id': 'TFT7_TrainerDragon',
#       'itemNames': ['TFT7_Item_TrainerSnax'],
#       'items': [41105],
#       'name': '',
#       'rarity': 8,
#       'tier': 3}]},
#    {'augments': ['TFT6_Augment_CyberneticUplink2',
#      'TFT6_Augment_Electrocharge2',
#      'TFT7_Augment_BruiserEmblem'],
#     'companion': {'content_ID': '8c27f67c-90b3-4355-9e90-6e92325c6017',
#      'skin_ID': 16,
#      'species': 'PetSpiritFox'},
#     'gold_left': 36,
#     'last_round': 27,
#     'level': 7,
#     'placement': 7,
#     'players_eliminated': 1,
#     'puuid': 'Ir-0m0U3Hd3ACBnbPe_qPgz20wAIap5d-9sQWwUOlhmwsc3IyErN5oZkLNPgDMaxRvsTpyfjr1QMpQ',
#     'time_eliminated': 1702.9312744140625,
#     'total_damage_to_players': 72,
#     'traits': [{'name': 'Set7_Astral',
#       'num_units': 3,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 3},
#      {'name': 'Set7_Bruiser',
#       'num_units': 4,
#       'style': 2,
#       'tier_current': 2,
#       'tier_total': 4},
#      {'name': 'Set7_Guild',
#       'num_units': 1,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 7},
#      {'name': 'Set7_Legend',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 1},
#      {'name': 'Set7_Ragewing',
#       'num_units': 1,
#       'style': 0,
#       'tier_current': 0,
#       'tier_total': 3},
#      {'name': 'Set7_Swiftshot',
#       'num_units': 4,
#       'style': 3,
#       'tier_current': 2,
#       'tier_total': 3},
#      {'name': 'Set7_Tempest',
#       'num_units': 2,
#       'style': 1,
#       'tier_current': 1,
#       'tier_total': 4}],
#     'units': [{'character_id': 'TFT7_Skarner',
#       'itemNames': [],
#       'items': [],
#       'name': 'Skarner',
#       'rarity': 0,
#       'tier': 2},
#      {'character_id': 'TFT7_Ezreal',
#       'itemNames': [],
#       'items': [],
#       'name': '',
#       'rarity': 0,
#       'tier': 1},
#      {'character_id': 'TFT7_Twitch',
#       'itemNames': ['TFT7_Item_BruiserEmblemItem'],
#       'items': [2305],
#       'name': '',
#       'rarity': 1,
#       'tier': 2},
#      {'character_id': 'TFT7_Varus',
#       'itemNames': ['TFT_Item_Deathblade',
#        'TFT_Item_GuinsoosRageblade',
#        'TFT_Item_RunaansHurricane'],
#       'items': [11, 23, 26],
#       'name': '',
#       'rarity': 2,
#       'tier': 3},
#      {'character_id': 'TFT7_Illaoi',
#       'itemNames': ['TFT_Item_RedBuff',
#        'TFT_Item_GargoyleStoneplate',
#        'TFT_Item_DragonsClaw'],
#       'items': [57, 56, 66],
#       'name': '',
#       'rarity': 2,
#       'tier': 3},
#      {'character_id': 'TFT7_Xayah',
#       'itemNames': ['TFT_Item_UnstableConcoction'],
#       'items': [49],
#       'name': '',
#       'rarity': 3,
#       'tier': 1},
#      {'character_id': 'TFT7_Ornn',
#       'itemNames': ['TFT_Item_NegatronCloak'],
#       'items': [6],
#       'name': '',
#       'rarity': 3,
#       'tier': 1}]}],
#   'queue_id': 1100,
#   'tft_game_type': 'standard',
#   'tft_set_core_name': 'TFTSet7',
#   'tft_set_number': 7}}

# %%
tft_tasks = loop.create_task(getTFTRecentMatches(accountId))

# %%
tft_tasks.result()
# Out:
# [{'metadata': {'data_version': '5',
#    'match_id': 'NA1_4379006381',
#    'participants': ['FSEAeloEaL4kf4eau2xefjxO3xjbbr0AfbHVAGMhfNRUUeAG5rcV9wuR2KKFvXyYwsMfDQmYpYqXCw',
#     'ZNCqjCYDCaSRCdoudTeQHLNUHcoc1PkEhED1jfmCyHegQjYfg5gqm4J2JPFMvveDWq5WN9tlZ-3LhQ',
#     'M-8X7VAadU_fmtndK-V1zxFFAcIRKF4QTLJr83kiXrCFMkPHPg1rz7rLmzE6Auyb4-G50q590A6S7w',
#     'wdtsCObSOruL1f9px4PN2ynDPxLote22FjtfootpHs6nL6qHS6wo3Ok9qCybluRDoEdqmd4fwct-_w',
#     'pPy5MdXKClKsVTrAFWj2k8tatNIWovBTghWRjyjfbEQRDNYVD5Cfj4hkEaYdEB7khH1J6oQ7QtKPLg',
#     'KCq1VZg7fYxSEjT6KztFEEKys_FgfcEdUlnoJe_2N1daqqKo_HGsU6IWdsgMZ2AyXPlctZKuNCqmTA',
#     'OsQA7o8LPtClUXRAOdvHadilUP9E_k6oAl7bfqQv_gCwaOAbCEqTa28DxODXfaETyMI2yqNUD-P8kw',
#     'Ir-0m0U3Hd3ACBnbPe_qPgz20wAIap5d-9sQWwUOlhmwsc3IyErN5oZkLNPgDMaxRvsTpyfjr1QMpQ']},
#   'info': {'game_datetime': 1658283530844,
#    'game_length': 2199.414794921875,
#    'game_version': 'Version 12.13.453.3037 (Jul 11 2022/18:39:20) [PUBLIC] <Releases/12.13>',
#    'participants': [{'augments': ['TFT7_Augment_GuildEmblem',
#       'TFT6_Augment_SecondWind2',
#       'TFT6_Augment_Diversify2'],
#      'companion': {'content_ID': 'b890d4df-181a-43da-861d-99a72afbc602',
#       'skin_ID': 2,
#       'species': 'PetChibiYasuo'},
#      'gold_left': 2,
#      'last_round': 26,
#      'level': 8,
#      'placement': 8,
#      'players_eliminated': 0,
#      'puuid': 'FSEAeloEaL4kf4eau2xefjxO3xjbbr0AfbHVAGMhfNRUUeAG5rcV9wuR2KKFvXyYwsMfDQmYpYqXCw',
#      'time_eliminated': 1613.69580078125,
#      'total_damage_to_players': 72,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Cavalier',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Dragonmancer',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Guardian',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Guild',
#        'num_units': 4,
#        'style': 2,
#        'tier_current': 4,
#        'tier_total': 7},
#       {'name': 'Set7_Ragewing',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Shapeshifter',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Shimmerscale',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Swiftshot',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3}],
#      'units': [{'character_id': 'TFT7_Sejuani',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Twitch',
#        'itemNames': ['TFT_Item_StatikkShiv', 'TFT_Item_ZekesHerald'],
#        'items': [24, 17],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Swain',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 2,
#        'tier': 1},
#       {'character_id': 'TFT7_Hecarim',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': ['TFT_Item_HextechGunblade'],
#        'items': [13],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_Xayah',
#        'itemNames': ['TFT7_Item_GuildEmblemItem',
#         'TFT_Item_GuinsoosRageblade',
#         'TFT_Item_MadredsBloodrazor'],
#        'items': [2318, 23, 12],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_DragonGold',
#        'itemNames': ['TFT7_Item_ShimmerscaleMogulsMail',
#         'TFT_Item_WarmogsArmor',
#         'TFT_Item_RedBuff'],
#        'items': [3000, 77, 57],
#        'name': '',
#        'rarity': 4,
#        'tier': 2}]},
#     {'augments': ['TFT6_Augment_TargetDummies',
#       'TFT6_Augment_CelestialBlessing2',
#       'TFT7_Augment_UrfsGrabBag1'],
#      'companion': {'content_ID': '3f358b24-6ca3-4943-85b1-8fb1981e93be',
#       'skin_ID': 16,
#       'species': 'PetChoncc'},
#      'gold_left': 5,
#      'last_round': 27,
#      'level': 7,
#      'placement': 6,
#      'players_eliminated': 0,
#      'puuid': 'ZNCqjCYDCaSRCdoudTeQHLNUHcoc1PkEhED1jfmCyHegQjYfg5gqm4J2JPFMvveDWq5WN9tlZ-3LhQ',
#      'time_eliminated': 1714.032470703125,
#      'total_damage_to_players': 55,
#      'traits': [{'name': 'Set7_Astral',
#        'num_units': 6,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 3},
#       {'name': 'Set7_Bruiser',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Guild',
#        'num_units': 1,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 7},
#       {'name': 'Set7_Mage',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Mystic',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Shapeshifter',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Swiftshot',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Whispers',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Vladimir',
#        'itemNames': [],
#        'items': [],
#        'name': 'Vladimir',
#        'rarity': 0,
#        'tier': 3},
#       {'character_id': 'TFT7_Skarner',
#        'itemNames': ['TFT_Item_ForceOfNature'],
#        'items': [88],
#        'name': 'Skarner',
#        'rarity': 0,
#        'tier': 3},
#       {'character_id': 'TFT7_Nidalee',
#        'itemNames': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_Bloodthirster'],
#        'items': [23, 16],
#        'name': 'Nidalee',
#        'rarity': 0,
#        'tier': 3},
#       {'character_id': 'TFT7_Nami',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 3},
#       {'character_id': 'TFT7_Twitch',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Elise',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 2,
#        'tier': 1},
#       {'character_id': 'TFT7_Varus',
#        'itemNames': ['TFT_Item_LastWhisper',
#         'TFT_Item_Bloodthirster',
#         'TFT_Item_GuinsoosRageblade'],
#        'items': [29, 16, 23],
#        'name': '',
#        'rarity': 2,
#        'tier': 3},
#       {'character_id': 'TFT7_Illaoi',
#        'itemNames': ['TFT7_Item_MageEmblemItem', 'TFT_Item_RedBuff'],
#        'items': [2311, 57],
#        'name': '',
#        'rarity': 2,
#        'tier': 2}]},
#     {'augments': ['TFT7_Augment_BruiserEmblem',
#       'TFT6_Augment_SecondWind2',
#       'TFT6_Augment_CyberneticUplink2'],
#      'companion': {'content_ID': 'b890d4df-181a-43da-861d-99a72afbc602',
#       'skin_ID': 2,
#       'species': 'PetChibiYasuo'},
#      'gold_left': 10,
#      'last_round': 33,
#      'level': 9,
#      'placement': 4,
#      'players_eliminated': 1,
#      'puuid': 'M-8X7VAadU_fmtndK-V1zxFFAcIRKF4QTLJr83kiXrCFMkPHPg1rz7rLmzE6Auyb4-G50q590A6S7w',
#      'time_eliminated': 2056.58251953125,
#      'total_damage_to_players': 95,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 4,
#        'style': 3,
#        'tier_current': 2,
#        'tier_total': 3},
#       {'name': 'Set7_Bruiser',
#        'num_units': 4,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Guardian',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Guild',
#        'num_units': 1,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 7},
#       {'name': 'Set7_Legend',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 1},
#       {'name': 'Set7_Mage',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Shapeshifter',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Tempest',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Whispers',
#        'num_units': 7,
#        'style': 3,
#        'tier_current': 3,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Thresh',
#        'itemNames': ['TFT7_Item_BruiserEmblemItem'],
#        'items': [2305],
#        'name': 'Thresh',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Qiyana',
#        'itemNames': ['TFT_Item_FrozenHeart', 'TFT_Item_GuinsoosRageblade'],
#        'items': [45, 23],
#        'name': '',
#        'rarity': 1,
#        'tier': 1},
#       {'character_id': 'TFT7_Elise',
#        'itemNames': ['TFT_Item_Zephyr'],
#        'items': [67],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Sylas',
#        'itemNames': ['TFT_Item_RedBuff'],
#        'items': [57],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': ['TFT_Item_BFSword'],
#        'items': [1],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_DragonPurple',
#        'itemNames': ['TFT_Item_Bloodthirster',
#         'TFT_Item_TitansResolve',
#         'TFT7_Item_AssassinEmblemItem'],
#        'items': [16, 25, 2325],
#        'name': '',
#        'rarity': 4,
#        'tier': 2},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': ['TFT_Item_SpearOfShojin'],
#        'items': [14],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_Pyke',
#        'itemNames': ['TFT_Item_WarmogsArmor'],
#        'items': [77],
#        'name': '',
#        'rarity': 5,
#        'tier': 1}]},
#     {'augments': ['TFT6_Augment_Electrocharge2',
#       'TFT7_Augment_GadgetExpert',
#       'TFT7_Augment_BestFriends2'],
#      'companion': {'content_ID': '85356c16-7748-4574-9ecc-13d79ccc3e5b',
#       'skin_ID': 20,
#       'species': 'PetBuglet'},
#      'gold_left': 8,
#      'last_round': 35,
#      'level': 9,
#      'placement': 1,
#      'players_eliminated': 2,
#      'puuid': 'wdtsCObSOruL1f9px4PN2ynDPxLote22FjtfootpHs6nL6qHS6wo3Ok9qCybluRDoEdqmd4fwct-_w',
#      'time_eliminated': 2191.193603515625,
#      'total_damage_to_players': 180,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Astral',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Bard',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 1},
#       {'name': 'Set7_Bruiser',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Guild',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 2,
#        'tier_total': 7},
#       {'name': 'Set7_Legend',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 1},
#       {'name': 'Set7_Mage',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Mystic',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Shimmerscale',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_SpellThief',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 1},
#       {'name': 'Set7_Tempest',
#        'num_units': 5,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4},
#       {'name': 'Set7_Whispers',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Nami',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Qiyana',
#        'itemNames': ['TFT_Item_IonicSpark'],
#        'items': [36],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Sylas',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': ['TFT_Item_Redemption', 'TFT_Item_IonicSpark'],
#        'items': [47, 36],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Zoe',
#        'itemNames': ['TFT_Item_Quicksilver',
#         'TFT_Item_StatikkShiv',
#         'TFT_Item_StatikkShiv'],
#        'items': [69, 24, 24],
#        'name': '',
#        'rarity': 5,
#        'tier': 1},
#       {'character_id': 'TFT7_Bard',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 5,
#        'tier': 1},
#       {'character_id': 'TFT7_AoShin',
#        'itemNames': ['TFT_Item_StatikkShiv',
#         'TFT_Item_HextechGunblade',
#         'TFT_Item_ArchangelsStaff'],
#        'items': [24, 13, 34],
#        'name': '',
#        'rarity': 6,
#        'tier': 2}]},
#     {'augments': ['TFT7_Augment_UrfsGrabBag1',
#       'TFT6_Augment_ThrillOfTheHunt2',
#       'TFT6_Augment_PortableForge'],
#      'companion': {'content_ID': 'd17f9a59-4ee6-4c41-9ba2-309dfb164885',
#       'skin_ID': 1,
#       'species': 'PetChibiYasuo'},
#      'gold_left': 4,
#      'last_round': 34,
#      'level': 8,
#      'placement': 3,
#      'players_eliminated': 2,
#      'puuid': 'pPy5MdXKClKsVTrAFWj2k8tatNIWovBTghWRjyjfbEQRDNYVD5Cfj4hkEaYdEB7khH1J6oQ7QtKPLg',
#      'time_eliminated': 2124.754150390625,
#      'total_damage_to_players': 94,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 4,
#        'style': 3,
#        'tier_current': 2,
#        'tier_total': 3},
#       {'name': 'Set7_Bruiser',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Guild',
#        'num_units': 1,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 7},
#       {'name': 'Set7_Jade',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Legend',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 1},
#       {'name': 'Set7_Scalescorn',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Shapeshifter',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Tempest',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Whispers',
#        'num_units': 4,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Qiyana',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Elise',
#        'itemNames': ['TFT7_Item_AssassinEmblemItem',
#         'TFT_Item_InfinityEdge',
#         'TFT_Item_ArchangelsStaff'],
#        'items': [2325, 19, 34],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Diana',
#        'itemNames': ['TFT_Item_MadredsBloodrazor',
#         'TFT_Item_IonicSpark',
#         'TFT4_Item_OrnnZhonyasParadox'],
#        'items': [12, 36, 9010],
#        'name': '',
#        'rarity': 2,
#        'tier': 3},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': ['TFT_Item_MadredsBloodrazor', 'TFT_Item_Bloodthirster'],
#        'items': [12, 16],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Neeko',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_DragonPurple',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 4,
#        'tier': 2},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': ['TFT_Item_Zephyr',
#         'TFT_Item_WarmogsArmor',
#         'TFT_Item_GargoyleStoneplate'],
#        'items': [67, 77, 56],
#        'name': '',
#        'rarity': 3,
#        'tier': 2}]},
#     {'augments': ['TFT6_Augment_SecondWind2',
#       'TFT7_Augment_FirstAidKit2',
#       'TFT7_Augment_PandorasBench'],
#      'companion': {'content_ID': '06da6495-55da-43c7-ba7d-a7114018eefc',
#       'skin_ID': 19,
#       'species': 'PetGrumpyLion'},
#      'gold_left': 0,
#      'last_round': 35,
#      'level': 8,
#      'placement': 2,
#      'players_eliminated': 1,
#      'puuid': 'KCq1VZg7fYxSEjT6KztFEEKys_FgfcEdUlnoJe_2N1daqqKo_HGsU6IWdsgMZ2AyXPlctZKuNCqmTA',
#      'time_eliminated': 2191.193603515625,
#      'total_damage_to_players': 120,
#      'traits': [{'name': 'Set7_Bruiser',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Dragonmancer',
#        'num_units': 6,
#        'style': 3,
#        'tier_current': 2,
#        'tier_total': 3},
#       {'name': 'Set7_Evoker',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Jade',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Legend',
#        'num_units': 3,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 1},
#       {'name': 'Set7_Mirage',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Ragewing',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Shimmerscale',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Swiftshot',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Tempest',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Warrior',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3}],
#      'units': [{'character_id': 'TFT7_Sett',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Karma',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Ashe',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_LeeSin',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Volibear',
#        'itemNames': ['TFT_Item_GuinsoosRageblade',
#         'TFT_Item_Bloodthirster',
#         'TFT_Item_Quicksilver'],
#        'items': [23, 16, 69],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Anivia',
#        'itemNames': ['TFT_Item_SparringGloves'],
#        'items': [9],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': ['TFT_Item_GargoyleStoneplate',
#         'TFT_Item_DragonsClaw',
#         'TFT_Item_IonicSpark'],
#        'items': [56, 66, 36],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Yasuo',
#        'itemNames': ['TFT_Item_FrozenHeart',
#         'TFT_Item_RedBuff',
#         'TFT_Item_GuardianAngel'],
#        'items': [45, 57, 94],
#        'name': '',
#        'rarity': 5,
#        'tier': 1}]},
#     {'augments': ['TFT7_Augment_MikaelsGift',
#       'TFT6_Augment_ComponentGrabBag',
#       'TFT6_Augment_Diversify2'],
#      'companion': {'content_ID': 'eb21cd43-7b67-4880-ae43-84a3e836057e',
#       'skin_ID': 19,
#       'species': 'PetFenroar'},
#      'gold_left': 0,
#      'last_round': 30,
#      'level': 8,
#      'placement': 5,
#      'players_eliminated': 0,
#      'puuid': 'OsQA7o8LPtClUXRAOdvHadilUP9E_k6oAl7bfqQv_gCwaOAbCEqTa28DxODXfaETyMI2yqNUD-P8kw',
#      'time_eliminated': 1885.76025390625,
#      'total_damage_to_players': 85,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Cannoneer',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Evoker',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Guardian',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Guild',
#        'num_units': 1,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 7},
#       {'name': 'Set7_Mystic',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Revel',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Scalescorn',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Shimmerscale',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Trainer',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 2}],
#      'units': [{'character_id': 'TFT7_Tristana',
#        'itemNames': ['TFT_Item_ZekesHerald', 'TFT_Item_PowerGauntlet'],
#        'items': [17, 79],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Braum',
#        'itemNames': ['TFT_Item_RedBuff', 'TFT_Item_GargoyleStoneplate'],
#        'items': [57, 56],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Lulu',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Corki',
#        'itemNames': ['TFT_Item_Deathblade',
#         'TFT_Item_InfinityEdge',
#         'TFT_Item_GuinsoosRageblade'],
#        'items': [11, 19, 23],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_Sona',
#        'itemNames': ['TFT_Item_LocketOfTheIronSolari'],
#        'items': [35],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_DragonGold',
#        'itemNames': ['TFT_Item_DragonsClaw',
#         'TFT7_Item_ShimmerscaleMogulsMail'],
#        'items': [66, 3000],
#        'name': '',
#        'rarity': 4,
#        'tier': 2},
#       {'character_id': 'TFT7_TrainerDragon',
#        'itemNames': ['TFT7_Item_TrainerSnax'],
#        'items': [41105],
#        'name': '',
#        'rarity': 8,
#        'tier': 3}]},
#     {'augments': ['TFT6_Augment_CyberneticUplink2',
#       'TFT6_Augment_Electrocharge2',
#       'TFT7_Augment_BruiserEmblem'],
#      'companion': {'content_ID': '8c27f67c-90b3-4355-9e90-6e92325c6017',
#       'skin_ID': 16,
#       'species': 'PetSpiritFox'},
#      'gold_left': 36,
#      'last_round': 27,
#      'level': 7,
#      'placement': 7,
#      'players_eliminated': 1,
#      'puuid': 'Ir-0m0U3Hd3ACBnbPe_qPgz20wAIap5d-9sQWwUOlhmwsc3IyErN5oZkLNPgDMaxRvsTpyfjr1QMpQ',
#      'time_eliminated': 1702.9312744140625,
#      'total_damage_to_players': 72,
#      'traits': [{'name': 'Set7_Astral',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Bruiser',
#        'num_units': 4,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4},
#       {'name': 'Set7_Guild',
#        'num_units': 1,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 7},
#       {'name': 'Set7_Legend',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 1},
#       {'name': 'Set7_Ragewing',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Swiftshot',
#        'num_units': 4,
#        'style': 3,
#        'tier_current': 2,
#        'tier_total': 3},
#       {'name': 'Set7_Tempest',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Skarner',
#        'itemNames': [],
#        'items': [],
#        'name': 'Skarner',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Ezreal',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 1},
#       {'character_id': 'TFT7_Twitch',
#        'itemNames': ['TFT7_Item_BruiserEmblemItem'],
#        'items': [2305],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Varus',
#        'itemNames': ['TFT_Item_Deathblade',
#         'TFT_Item_GuinsoosRageblade',
#         'TFT_Item_RunaansHurricane'],
#        'items': [11, 23, 26],
#        'name': '',
#        'rarity': 2,
#        'tier': 3},
#       {'character_id': 'TFT7_Illaoi',
#        'itemNames': ['TFT_Item_RedBuff',
#         'TFT_Item_GargoyleStoneplate',
#         'TFT_Item_DragonsClaw'],
#        'items': [57, 56, 66],
#        'name': '',
#        'rarity': 2,
#        'tier': 3},
#       {'character_id': 'TFT7_Xayah',
#        'itemNames': ['TFT_Item_UnstableConcoction'],
#        'items': [49],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': ['TFT_Item_NegatronCloak'],
#        'items': [6],
#        'name': '',
#        'rarity': 3,
#        'tier': 1}]}],
#    'queue_id': 1100,
#    'tft_game_type': 'standard',
#    'tft_set_core_name': 'TFTSet7',
#    'tft_set_number': 7}},
#  {'metadata': {'data_version': '5',
#    'match_id': 'NA1_4378413824',
#    'participants': ['jXj2IdHon8gKMSL4zBk88gxWaaEGXWq5cV2i6TxM9QyYqLx4vTy44enF6GIy_eD0-b-Hbao2KXod-g',
#     'pPy5MdXKClKsVTrAFWj2k8tatNIWovBTghWRjyjfbEQRDNYVD5Cfj4hkEaYdEB7khH1J6oQ7QtKPLg',
#     '0iGtiptjYF2UCseXKcDwTcZvYn3McLzvh-0ngLegif0Z4mEy0eXPba3YAOxMEMiTqKbuAotjd1gwZQ',
#     'qIOf-G8wi9gNiDpTREWwFzSaNemC07wU2hI1RKcHKfvk2wLcbQ4oV2wwd4iL4Z6IBHIvQ1D6DpowUg',
#     'nuw54hC7IHw0FIbuwwyNauNlGlsRcaUc5M_ZLtQHLXScFaEszI-UlDUnNTJbal8BTc559Zr9jwZ1Xg',
#     '4O7mumVvuhrPzp0-YVksih7w4-MNyAFuaJBix29bjdfFTHhZ631HD9jrvEVd1TlzkvtMgu906Vgm0Q',
#     'mNaEj8qhKS6leT9xrZgIL2I6G_1VqqqQByQtxpeQuks3VCpDWwYvQuKq7J9EOeOEwZlvUIxZzUBvJg',
#     '2HF2TmbBbEbjDXFZsQ0kDgpmbbd5H7JBykM2IHxn8_PeLn7SRuGdqHaGBGTMQolRvlGGzEQMkiFGzg']},
#   'info': {'game_datetime': 1658215907727,
#    'game_length': 2175.8369140625,
#    'game_version': 'Version 12.13.453.3037 (Jul 11 2022/18:39:20) [PUBLIC] <Releases/12.13>',
#    'participants': [{'augments': ['TFT7_Augment_RevelPartyTime',
#       'TFT7_Augment_RevelTrait',
#       'TFT7_Augment_GadgetExpert'],
#      'companion': {'content_ID': 'ebf6a5d5-82c6-4c49-906a-7dea5373b032',
#       'skin_ID': 4,
#       'species': 'PetPenguKnight'},
#      'gold_left': 12,
#      'last_round': 37,
#      'level': 9,
#      'placement': 1,
#      'players_eliminated': 3,
#      'puuid': 'jXj2IdHon8gKMSL4zBk88gxWaaEGXWq5cV2i6TxM9QyYqLx4vTy44enF6GIy_eD0-b-Hbao2KXod-g',
#      'time_eliminated': 2167.68505859375,
#      'total_damage_to_players': 150,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Astral',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Cannoneer',
#        'num_units': 3,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Evoker',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Guardian',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Guild',
#        'num_units': 1,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 7},
#       {'name': 'Set7_Mage',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Mystic',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Revel',
#        'num_units': 4,
#        'style': 3,
#        'tier_current': 3,
#        'tier_total': 4},
#       {'name': 'Set7_Shimmerscale',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Trainer',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Whispers',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Nami',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 1},
#       {'character_id': 'TFT7_Jinx',
#        'itemNames': ['TFT_Item_ZekesHerald',
#         'TFT_Item_StatikkShiv',
#         'TFT_Item_LastWhisper'],
#        'items': [17, 24, 29],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Tristana',
#        'itemNames': ['TFT_Item_LastWhisper'],
#        'items': [29],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Lulu',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Corki',
#        'itemNames': ['TFT_Item_MadredsBloodrazor',
#         'TFT_Item_InfinityEdge',
#         'TFT7_Item_ShimmerscaleDravensAxe'],
#        'items': [12, 19, 3001],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': ['TFT_Item_ForceOfNature'],
#        'items': [88],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_Sona',
#        'itemNames': ['TFT_Item_HextechGunblade', 'TFT_Item_SeraphsEmbrace'],
#        'items': [13, 44],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_DragonGold',
#        'itemNames': ['TFT_Item_IonicSpark',
#         'TFT_Item_TitansResolve',
#         'TFT_Item_RedBuff'],
#        'items': [36, 25, 57],
#        'name': '',
#        'rarity': 4,
#        'tier': 2},
#       {'character_id': 'TFT7_Pyke',
#        'itemNames': ['TFT_Item_UnstableConcoction'],
#        'items': [49],
#        'name': '',
#        'rarity': 5,
#        'tier': 2},
#       {'character_id': 'TFT7_TrainerDragon',
#        'itemNames': ['TFT7_Item_TrainerSnax'],
#        'items': [41105],
#        'name': '',
#        'rarity': 8,
#        'tier': 4}]},
#     {'augments': ['TFT7_Augment_ClutteredMind',
#       'TFT6_Augment_ItemGrabBag1',
#       'TFT7_Augment_BestFriends2'],
#      'companion': {'content_ID': 'd17f9a59-4ee6-4c41-9ba2-309dfb164885',
#       'skin_ID': 1,
#       'species': 'PetChibiYasuo'},
#      'gold_left': 2,
#      'last_round': 35,
#      'level': 9,
#      'placement': 3,
#      'players_eliminated': 1,
#      'puuid': 'pPy5MdXKClKsVTrAFWj2k8tatNIWovBTghWRjyjfbEQRDNYVD5Cfj4hkEaYdEB7khH1J6oQ7QtKPLg',
#      'time_eliminated': 2074.835693359375,
#      'total_damage_to_players': 127,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Bard',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 1},
#       {'name': 'Set7_Bruiser',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Cavalier',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Guild',
#        'num_units': 4,
#        'style': 2,
#        'tier_current': 4,
#        'tier_total': 7},
#       {'name': 'Set7_Legend',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 1},
#       {'name': 'Set7_Mystic',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Ragewing',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Swiftshot',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Tempest',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Warrior',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3}],
#      'units': [{'character_id': 'TFT7_Sejuani',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Qiyana',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 1},
#       {'character_id': 'TFT7_Shen',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Twitch',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Hecarim',
#        'itemNames': ['TFT_Item_Shroud'],
#        'items': [59],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': ['TFT_Item_InfinityEdge',
#         'TFT_Item_LastWhisper',
#         'TFT_Item_StatikkShiv'],
#        'items': [19, 29, 24],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Xayah',
#        'itemNames': ['TFT_Item_LastWhisper',
#         'TFT_Item_GuinsoosRageblade',
#         'TFT_Item_InfinityEdge'],
#        'items': [29, 23, 19],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': ['TFT_Item_RedBuff', 'TFT_Item_TitansResolve'],
#        'items': [57, 25],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Bard',
#        'itemNames': ['TFT_Item_SeraphsEmbrace'],
#        'items': [44],
#        'name': '',
#        'rarity': 5,
#        'tier': 2}]},
#     {'augments': ['TFT6_Augment_CyberneticUplink2',
#       'TFT6_Augment_ThrillOfTheHunt1',
#       'TFT6_Augment_SalvageBin'],
#      'companion': {'content_ID': '89bb8b2c-344e-4725-aa4d-f5f81e894480',
#       'skin_ID': 25,
#       'species': 'PetQiyanaDog'},
#      'gold_left': 0,
#      'last_round': 31,
#      'level': 8,
#      'placement': 5,
#      'players_eliminated': 1,
#      'puuid': '0iGtiptjYF2UCseXKcDwTcZvYn3McLzvh-0ngLegif0Z4mEy0eXPba3YAOxMEMiTqKbuAotjd1gwZQ',
#      'time_eliminated': 1860.420166015625,
#      'total_damage_to_players': 87,
#      'traits': [{'name': 'Set7_Astral',
#        'num_units': 2,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Bruiser',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Cavalier',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Guardian',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Guild',
#        'num_units': 1,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 7},
#       {'name': 'Set7_Mage',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Mirage',
#        'num_units': 4,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4},
#       {'name': 'Set7_Mystic',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Ragewing',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Scalescorn',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3}],
#      'units': [{'character_id': 'TFT7_Skarner',
#        'itemNames': ['TFT_Item_BrambleVest',
#         'TFT_Item_GargoyleStoneplate',
#         'TFT_Item_TitanicHydra'],
#        'items': [55, 56, 27],
#        'name': 'Skarner',
#        'rarity': 0,
#        'tier': 3},
#       {'character_id': 'TFT7_Leona',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 1},
#       {'character_id': 'TFT7_Nami',
#        'itemNames': ['TFT_Item_ArchangelsStaff',
#         'TFT_Item_StatikkShiv',
#         'TFT_Item_SpearOfShojin'],
#        'items': [34, 24, 14],
#        'name': '',
#        'rarity': 1,
#        'tier': 3},
#       {'character_id': 'TFT7_Lillia',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Ryze',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 2,
#        'tier': 1},
#       {'character_id': 'TFT7_Hecarim',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_DragonBlue',
#        'itemNames': ['TFT_Item_GuinsoosRageblade',
#         'TFT_Item_GuinsoosRageblade',
#         'TFT_Item_MadredsBloodrazor'],
#        'items': [23, 23, 12],
#        'name': '',
#        'rarity': 4,
#        'tier': 2}]},
#     {'augments': ['TFT6_Augment_TrueTwos',
#       'TFT7_Augment_BestFriends1',
#       'TFT7_Augment_FirstAidKit2'],
#      'companion': {'content_ID': '5e171fec-60fe-470f-b922-47927f5e69a6',
#       'skin_ID': 21,
#       'species': 'PetSpiritFox'},
#      'gold_left': 0,
#      'last_round': 37,
#      'level': 8,
#      'placement': 2,
#      'players_eliminated': 2,
#      'puuid': 'qIOf-G8wi9gNiDpTREWwFzSaNemC07wU2hI1RKcHKfvk2wLcbQ4oV2wwd4iL4Z6IBHIvQ1D6DpowUg',
#      'time_eliminated': 2167.68505859375,
#      'total_damage_to_players': 142,
#      'traits': [{'name': 'Set7_Bruiser',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Dragonmancer',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Evoker',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Legend',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 1},
#       {'name': 'Set7_Mage',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Mirage',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Mystic',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Shimmerscale',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_SpellThief',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 1},
#       {'name': 'Set7_Tempest',
#        'num_units': 4,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4},
#       {'name': 'Set7_Trainer',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Warrior',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Whispers',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Heimerdinger',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Lulu',
#        'itemNames': ['TFT_Item_Chalice'],
#        'items': [46],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Sylas',
#        'itemNames': ['TFT_Item_DragonsClaw',
#         'TFT_Item_TitanicHydra',
#         'TFT_Item_Redemption'],
#        'items': [66, 27, 47],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Zoe',
#        'itemNames': ['TFT_Item_Chalice', 'TFT_Item_NeedlesslyLargeRod'],
#        'items': [46, 3],
#        'name': '',
#        'rarity': 5,
#        'tier': 1},
#       {'character_id': 'TFT7_Yasuo',
#        'itemNames': ['TFT_Item_IonicSpark'],
#        'items': [36],
#        'name': '',
#        'rarity': 5,
#        'tier': 1},
#       {'character_id': 'TFT7_AoShin',
#        'itemNames': ['TFT_Item_StatikkShiv',
#         'TFT_Item_JeweledGauntlet',
#         'TFT_Item_SeraphsEmbrace'],
#        'items': [24, 39, 44],
#        'name': '',
#        'rarity': 6,
#        'tier': 2},
#       {'character_id': 'TFT7_TrainerDragon',
#        'itemNames': ['TFT7_Item_TrainerSnax'],
#        'items': [41105],
#        'name': '',
#        'rarity': 8,
#        'tier': 4}]},
#     {'augments': ['TFT6_Augment_JeweledLotus',
#       'TFT6_Augment_Diversify1',
#       'TFT6_Augment_PortableForge'],
#      'companion': {'content_ID': '19cf229e-c8ab-4718-9121-364e69c85c68',
#       'skin_ID': 22,
#       'species': 'PetDowsie'},
#      'gold_left': 18,
#      'last_round': 28,
#      'level': 7,
#      'placement': 8,
#      'players_eliminated': 0,
#      'puuid': 'nuw54hC7IHw0FIbuwwyNauNlGlsRcaUc5M_ZLtQHLXScFaEszI-UlDUnNTJbal8BTc559Zr9jwZ1Xg',
#      'time_eliminated': 1691.2471923828125,
#      'total_damage_to_players': 69,
#      'traits': [{'name': 'Set7_Astral',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Bruiser',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Evoker',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Guild',
#        'num_units': 1,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 7},
#       {'name': 'Set7_Mage',
#        'num_units': 5,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4},
#       {'name': 'Set7_Mystic',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Trainer',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Whispers',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Vladimir',
#        'itemNames': [],
#        'items': [],
#        'name': 'Vladimir',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Heimerdinger',
#        'itemNames': ['TFT_Item_Chalice'],
#        'items': [46],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Nami',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Lulu',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 2,
#        'tier': 1},
#       {'character_id': 'TFT7_Ryze',
#        'itemNames': ['TFT_Item_HextechGunblade',
#         'TFT_Item_ArchangelsStaff',
#         'TFT_Item_SpearOfShojin'],
#        'items': [13, 34, 14],
#        'name': '',
#        'rarity': 2,
#        'tier': 3},
#       {'character_id': 'TFT7_Sylas',
#        'itemNames': ['TFT_Item_WarmogsArmor',
#         'TFT4_Item_OrnnAnimaVisage',
#         'TFT_Item_GargoyleStoneplate'],
#        'items': [77, 9001, 56],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Illaoi',
#        'itemNames': ['TFT_Item_RedBuff'],
#        'items': [57],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_TrainerDragon',
#        'itemNames': ['TFT7_Item_TrainerSnax'],
#        'items': [41105],
#        'name': '',
#        'rarity': 8,
#        'tier': 3}]},
#     {'augments': ['TFT6_Augment_ThreesCompany',
#       'TFT6_Augment_SecondWind1',
#       'TFT7_Augment_AxiomArc2'],
#      'companion': {'content_ID': 'b890d4df-181a-43da-861d-99a72afbc602',
#       'skin_ID': 2,
#       'species': 'PetChibiYasuo'},
#      'gold_left': 21,
#      'last_round': 30,
#      'level': 8,
#      'placement': 6,
#      'players_eliminated': 0,
#      'puuid': '4O7mumVvuhrPzp0-YVksih7w4-MNyAFuaJBix29bjdfFTHhZ631HD9jrvEVd1TlzkvtMgu906Vgm0Q',
#      'time_eliminated': 1804.5736083984375,
#      'total_damage_to_players': 84,
#      'traits': [{'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Dragonmancer',
#        'num_units': 2,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Evoker',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Guardian',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Jade',
#        'num_units': 9,
#        'style': 3,
#        'tier_current': 3,
#        'tier_total': 4},
#       {'name': 'Set7_Legend',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 1},
#       {'name': 'Set7_Mystic',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Shapeshifter',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Swiftshot',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3}],
#      'units': [{'character_id': 'TFT7_Karma',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Taric',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Gnar',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Ashe',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 3},
#       {'character_id': 'TFT7_Anivia',
#        'itemNames': ['TFT_Item_SpearOfShojin',
#         'TFT_Item_Morellonomicon',
#         'TFT_Item_JeweledGauntlet'],
#        'items': [14, 37, 39],
#        'name': '',
#        'rarity': 2,
#        'tier': 2},
#       {'character_id': 'TFT7_Neeko',
#        'itemNames': ['TFT_Item_Quicksilver'],
#        'items': [69],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_DragonGreen',
#        'itemNames': ['TFT_Item_Bloodthirster',
#         'TFT_Item_TitansResolve',
#         'TFT_Item_GuardianAngel'],
#        'items': [16, 25, 94],
#        'name': '',
#        'rarity': 4,
#        'tier': 2}]},
#     {'augments': ['TFT6_Augment_TargetDummies',
#       'TFT7_Augment_BestFriends1',
#       'TFT6_Augment_CelestialBlessing2'],
#      'companion': {'content_ID': '90d50b57-43c0-4e9f-9a9f-d1bebb05da4f',
#       'skin_ID': 1,
#       'species': 'PetBallDragon'},
#      'gold_left': 4,
#      'last_round': 28,
#      'level': 8,
#      'placement': 7,
#      'players_eliminated': 0,
#      'puuid': 'mNaEj8qhKS6leT9xrZgIL2I6G_1VqqqQByQtxpeQuks3VCpDWwYvQuKq7J9EOeOEwZlvUIxZzUBvJg',
#      'time_eliminated': 1702.4385986328125,
#      'total_damage_to_players': 59,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Astral',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Bruiser',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4},
#       {'name': 'Set7_Guild',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 2,
#        'tier_total': 7},
#       {'name': 'Set7_Legend',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 1},
#       {'name': 'Set7_Mage',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Mystic',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Swiftshot',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Tempest',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Ezreal',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 0,
#        'tier': 2},
#       {'character_id': 'TFT7_Nami',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Twitch',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Varus',
#        'itemNames': ['TFT_Item_GuinsoosRageblade', 'TFT_Item_LastWhisper'],
#        'items': [23, 29],
#        'name': '',
#        'rarity': 2,
#        'tier': 3},
#       {'character_id': 'TFT7_Illaoi',
#        'itemNames': ['TFT_Item_WarmogsArmor'],
#        'items': [77],
#        'name': '',
#        'rarity': 2,
#        'tier': 3},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': ['TFT_Item_InfinityEdge',
#         'TFT_Item_FrozenHeart',
#         'TFT_Item_UnstableConcoction'],
#        'items': [19, 45, 49],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 3,
#        'tier': 1},
#       {'character_id': 'TFT7_Ornn',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 3,
#        'tier': 1}]},
#     {'augments': ['TFT7_Augment_ShimmerscaleTrait',
#       'TFT6_Augment_FirstAidKit',
#       'TFT7_Augment_RagewingEmblem'],
#      'companion': {'content_ID': '1417c8b3-9ebb-4d56-b9cf-6cb3af34c538',
#       'skin_ID': 4,
#       'species': 'PetSGCat'},
#      'gold_left': 37,
#      'last_round': 31,
#      'level': 8,
#      'placement': 4,
#      'players_eliminated': 0,
#      'puuid': '2HF2TmbBbEbjDXFZsQ0kDgpmbbd5H7JBykM2IHxn8_PeLn7SRuGdqHaGBGTMQolRvlGGzEQMkiFGzg',
#      'time_eliminated': 1864.0509033203125,
#      'total_damage_to_players': 88,
#      'traits': [{'name': 'Set7_Assassin',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Bard',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 1},
#       {'name': 'Set7_Dragon',
#        'num_units': 1,
#        'style': 3,
#        'tier_current': 1,
#        'tier_total': 2},
#       {'name': 'Set7_Guardian',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 3},
#       {'name': 'Set7_Guild',
#        'num_units': 3,
#        'style': 2,
#        'tier_current': 3,
#        'tier_total': 7},
#       {'name': 'Set7_Mystic',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4},
#       {'name': 'Set7_Ragewing',
#        'num_units': 3,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Shimmerscale',
#        'num_units': 5,
#        'style': 2,
#        'tier_current': 2,
#        'tier_total': 4},
#       {'name': 'Set7_Swiftshot',
#        'num_units': 2,
#        'style': 1,
#        'tier_current': 1,
#        'tier_total': 3},
#       {'name': 'Set7_Whispers',
#        'num_units': 1,
#        'style': 0,
#        'tier_current': 0,
#        'tier_total': 4}],
#      'units': [{'character_id': 'TFT7_Kayn',
#        'itemNames': ['TFT_Item_ThiefsGloves',
#         'TFT_Item_Quicksilver',
#         'TFT_Item_RabadonsDeathcap'],
#        'items': [99, 69, 33],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Twitch',
#        'itemNames': ['TFT7_Item_RagewingEmblemItem',
#         'TFT7_Item_ShimmerscaleHeartOfGold',
#         'TFT_Item_StatikkShiv'],
#        'items': [2315, 3002, 24],
#        'name': '',
#        'rarity': 1,
#        'tier': 2},
#       {'character_id': 'TFT7_Talon',
#        'itemNames': ['TFT_Item_InfinityEdge', 'TFT_Item_Bloodthirster'],
#        'items': [19, 16],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_Xayah',
#        'itemNames': ['TFT7_Item_ShimmerscaleDravensAxe',
#         'TFT_Item_GuinsoosRageblade',
#         'TFT_Item_MadredsBloodrazor'],
#        'items': [3001, 23, 12],
#        'name': '',
#        'rarity': 3,
#        'tier': 2},
#       {'character_id': 'TFT7_DragonGold',
#        'itemNames': ['TFT_Item_GargoyleStoneplate',
#         'TFT_Item_WarmogsArmor',
#         'TFT_Item_RedBuff'],
#        'items': [56, 77, 57],
#        'name': '',
#        'rarity': 4,
#        'tier': 2},
#       {'character_id': 'TFT7_Bard',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 5,
#        'tier': 1},
#       {'character_id': 'TFT7_Pyke',
#        'itemNames': [],
#        'items': [],
#        'name': '',
#        'rarity': 5,
#        'tier': 1}]}],
#    'queue_id': 1100,
#    'tft_game_type': 'standard',
#    'tft_set_core_name': 'TFTSet7',
#    'tft_set_number': 7}}]

# %%
tft_tasks
# Out:
# <Task finished name='Task-17' coro=<getTFTRecentMatches() done, defined at C:\Users\furyx\AppData\Local\Temp\ipykernel_16772\154215841.py:56> result=[{'info': {'game_datetime': 1656042128699, 'game_length': 2145.134033203125, 'game_version': 'Version 12.1...leases/12.12>', 'participants': [{'augments': ['TFT6_Augment_SunfireBoard', 'TFT7_Augment_BandOfThieves1', 'TFT6_Augment_ItemGrabBag1'], 'companion': {'content_ID': '9a78016d-808...-d57e22838938', 'skin_ID': 12, 'species': 'PetChoncc'}, 'gold_left': 1, 'last_round': 20, ...}, {'augments': ['TFT6_Augment_ThreesCompany', 'TFT6_Augment_LudensEcho1', 'TFT7_Augment_BestFriends1'], 'companion': {'content_ID': 'c0f093f8-447...-37f277859b44', 'skin_ID': 13, 'species': 'PetDSSwordGuy'}, 'gold_left': 0, 'last_round': 27, ...}, {'augments': ['TFT6_Augment...illOfTheHunt2', 'TFT7_Augment_Preparation', 'TFT7_Augment_BandOfThieves1'], 'companion': {'content_ID': 'ba8d6df7-130...-498d7ae4fc02', 'skin_ID': 6, 'species': 'PetDuckbill'}, 'gold_left': 0, 'last_round': 37, ...}, {'augments': ['TFT6_Augment_Featherweights2', 'TFT6_Augment...tialBlessing1', 'TFT6_Augment_MakeshiftArmor1'], 'companion': {'content_ID': '9e35c9bf-707...-b042ca54ceb3', 'skin_ID': 34, 'species': 'PetPegasus'}, 'gold_left': 23, 'last_round': 35, ...}, {'augments': ['TFT6_Augment_BlueBattery2', 'TFT6_Augment_Diversify1', 'TFT6_Augment...tialBlessing1'], 'companion': {'content_ID': 'd17f9a59-4ee...-309dfb164885', 'skin_ID': 1, 'species': 'PetChibiYasuo'}, 'gold_left': 19, 'last_round': 37, ...}, {'augments': ['TFT6_Augment_BlueBattery2', 'TFT6_Augment_Electrocharge1', 'TFT7_Augment_AxiomArc1'], 'companion': {'content_ID': '9f80c9fd-c74...-4c2a6ec6a652', 'skin_ID': 24, 'species': 'PetQiyanaDog'}, 'gold_left': 0, 'last_round': 27, ...}, ...], ...}, 'metadata': {'data_version': '5', 'match_id': 'NA1_4352620325', 'participants': ['6dTpXYB8ul1_...CgPscQQndEkHQ', 'Ky04TWNttpY1...Wvc0anscDtvuQ', '9UbiX023h7cq...EY42fvlipzn1w', 'XMeqQm5aeYLC...atS-DKeDaUwWA', 'K8izf-1-ovMV...JFsOFa_kSEzpg', 'keG7tUcvWG_j...BSajEeWWON5zw', ...]}}, {'info': {'game_datetime': 1655942105595, 'game_length': 2443.365234375, 'game_version': 'Version 12.1...leases/12.11>', 'participants': [{'augments': ['TFT7_Augment_RagewingEmblem', 'TFT6_Augment_PandorasItems', 'TFT6_Augment_SunfireBoard'], 'companion': {'content_ID': 'df9aaacd-a07...-7668a8e80216', 'skin_ID': 19, 'species': 'PetDSSwordGuy'}, 'gold_left': 1, 'last_round': 28, ...}, {'augments': ['TFT6_Augment_MakeshiftArmor2', 'TFT6_Augment_Weakspot', 'TFT6_Augment_Diversify2'], 'companion': {'content_ID': 'd17f9a59-4ee...-309dfb164885', 'skin_ID': 1, 'species': 'PetChibiYasuo'}, 'gold_left': 3, 'last_round': 34, ...}, {'augments': ['TFT6_Augment...tialBlessing2', 'TFT6_Augment_Featherweights1', 'TFT7_Augment...dGearUpgrades'], 'companion': {'content_ID': '8c27f67c-90b...-6e92325c6053', 'skin_ID': 12, 'species': 'PetSpiritFox'}, 'gold_left': 1, 'last_round': 38, ...}, {'augments': ['TFT6_Augment_ThreesCompany', 'TFT6_Augment_SecondWind1', 'TFT7_Augment_BruiserEmblem'], 'companion': {'content_ID': '42f00aaf-97d...-c904818a74a8', 'skin_ID': 27, 'species': 'PetQiyanaDog'}, 'gold_left': 3, 'last_round': 35, ...}, {'augments': ['TFT6_Augment_ClearMind', 'TFT6_Augment_SecondWind1', 'TFT6_Augment_SunfireBoard'], 'companion': {'content_ID': '06da6495-55d...-a7114018eefc', 'skin_ID': 19, 'species': 'PetGrumpyLion'}, 'gold_left': 5, 'last_round': 31, ...}, {'augments': ['TFT7_Augment_Bloodlust1', 'TFT7_Augment_RagewingTrait', 'TFT6_Augment_PortableForge'], 'companion': {'content_ID': '86557104-3db...-c2f7fb040c6c', 'skin_ID': 7, 'species': 'PetDSWhale'}, 'gold_left': 2, 'last_round': 30, ...}, ...], ...}, 'metadata': {'data_version': '5', 'match_id': 'NA1_4351178367', 'participants': ['CphfMV0t1X4r..._m9ZpM67MWQsA', 'K8izf-1-ovMV...JFsOFa_kSEzpg', '9rMJVvpWuNSL...xgxkoKchPtw5Q', 'HB4Lm4jwPTG-...orp-uavSoo5cg', 'cePEdsthDITb...uS2z3zk925Y0g', '4wonLnCYabA9...n2vqpzJhugYHA', ...]}}]>

# %%
await panth.get_tft_challenger_league()
# Out:
# https://na1.api.riotgames.com/tft/league/v1/challenger
# 200
# <CIMultiDictProxy('Date': 'Thu, 21 Jul 2022 02:07:58 GMT', 'Content-Type': 'application/json;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'X-App-Rate-Limit': '20:1,100:120', 'X-App-Rate-Limit-Count': '1:1,1:120', 'X-Method-Rate-Limit': '30:10,500:600', 'X-Method-Rate-Limit-Count': '1:10,1:600', 'X-Riot-Edge-Trace-Id': 'ec5aeef6-ea59-420d-8b85-5c33daa5db89', 'Content-Encoding': 'gzip', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, PUT, DELETE, POST, OPTIONS', 'Access-Control-Allow-Headers': 'DNT,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range', 'Access-Control-Expose-Headers': 'Content-Length,Content-Range')>
# {'tier': 'CHALLENGER',
#  'leagueId': '2d3f9192-2b1d-3204-a9c8-c58bd570ea65',
#  'queue': 'RANKED_TFT',
#  'name': "Garen's Dawnbringers",
#  'entries': [{'summonerId': 'R0oET5LXfysEmZNTovwZwhpQrk1ueaJ1idJRrEddzg8CwdM',
#    'summonerName': 'P31812',
#    'leaguePoints': 609,
#    'rank': 'I',
#    'wins': 136,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'lbWYL1okf1EaByi6wjqID0oSNKqVjjNFwlOhVXl2yKNI12U',
#    'summonerName': 'Amde',
#    'leaguePoints': 1064,
#    'rank': 'I',
#    'wins': 220,
#    'losses': 166,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '77CbmR2tCtp1IiUt5gKbB0W2420b5UljUC42ZM8i8uEj9GU',
#    'summonerName': 'Béaster',
#    'leaguePoints': 1004,
#    'rank': 'I',
#    'wins': 213,
#    'losses': 142,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'K9a1aRQGJ3UkDSPvjqt-rTMcnmH_9aPAfshQ7NKNFEInBJQ',
#    'summonerName': 'sètsuko',
#    'leaguePoints': 1316,
#    'rank': 'I',
#    'wins': 488,
#    'losses': 256,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'QJl3CXrw4QY-M2JMhCgxyTk-qfKAoA58c8wHxJC2XLVmZfo',
#    'summonerName': 'oshwott2844',
#    'leaguePoints': 658,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 87,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'SisZGT-SlQzWtZyJ1YTklpHqcRSjLNzsmbN2hTVxkJMQNHdawXjg-ueZIQ',
#    'summonerName': 'kpk618',
#    'leaguePoints': 782,
#    'rank': 'I',
#    'wins': 215,
#    'losses': 175,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'u4CgZ0RgKdwMT8XkzicWH4JtiwNQYZ_Ghsdm-cGkSi2VLog8WkXKKKpJPQ',
#    'summonerName': 'TftGodBinBin1',
#    'leaguePoints': 700,
#    'rank': 'I',
#    'wins': 137,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tELSehsiIZp5BR7bth6O3lV6YCns5IlrQ11Hson8NbFaE0g',
#    'summonerName': 'Kyivix',
#    'leaguePoints': 793,
#    'rank': 'I',
#    'wins': 153,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TGJytF0lbaVYLYV6oKJ656bIazRYKxqZ6SZobKPQpukgTFrj',
#    'summonerName': 'throwawayKJ',
#    'leaguePoints': 562,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 117,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'O6yYpeFvTNWkPUqv9tqWhTlv8xI4g_Zc5GRp5f_ds9Ud8cc',
#    'summonerName': 'theOnLy1z',
#    'leaguePoints': 1661,
#    'rank': 'I',
#    'wins': 277,
#    'losses': 164,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ViZetIGGi0WjyWDkBgkuMcHZ3v0eRCHT_BPOg2ifWAd9q_XvjqMjiEheFw',
#    'summonerName': 'lemonPaprika',
#    'leaguePoints': 786,
#    'rank': 'I',
#    'wins': 191,
#    'losses': 156,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'BWdzBhHZjKk_cmtQoVIYDLF4Imb0UZ8IV4yt4crZQwnGn9rn',
#    'summonerName': 'uwudamndaniel',
#    'leaguePoints': 652,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'M6EuSEms9OIkdVBIrGi4SQW_tyt_CoV_Zt42pBbbtjLQYQQf',
#    'summonerName': 'HT ARaye',
#    'leaguePoints': 658,
#    'rank': 'I',
#    'wins': 120,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '458TjxYTXufrhfaT0YLtBG2P1jQdkUPy2mloKIuoL4SSsr8',
#    'summonerName': 'sehm',
#    'leaguePoints': 604,
#    'rank': 'I',
#    'wins': 169,
#    'losses': 138,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'qx7aeAgD73dG_7Zjsjr1eDKoehNI2BXJ3crrpOS7-emQfjE',
#    'summonerName': 'dementedgraph',
#    'leaguePoints': 706,
#    'rank': 'I',
#    'wins': 186,
#    'losses': 149,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'I-1uh1O0Eorau0H2FsPK8f71C4BikqrXiFCQqWftVlhMeOzg',
#    'summonerName': 'xjqlmc',
#    'leaguePoints': 959,
#    'rank': 'I',
#    'wins': 77,
#    'losses': 31,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ofBlFpMjuVuH5lGLrSsCufkS3UjuCTU5xIL_dI_Td23SD0E',
#    'summonerName': 'Kranos',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 132,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'J2JbYFOsGyvg7O6MIKSgw3-FpM-K-DqTac36b7X5yOD3yx0',
#    'summonerName': 'Yung Nigiri',
#    'leaguePoints': 1026,
#    'rank': 'I',
#    'wins': 208,
#    'losses': 161,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'k8clZf7gh4OfXpwNgycGDxeRtvtxKOlsHQVrstnMJQRP8EzmgKjVkcrTmA',
#    'summonerName': 'robivankenob',
#    'leaguePoints': 1165,
#    'rank': 'I',
#    'wins': 358,
#    'losses': 282,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tZWsMnObj4OoDE9O83VO1vFv3kFjfNLuXtuVKyttfyDL7wc',
#    'summonerName': 'jdzielinski22',
#    'leaguePoints': 808,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 90,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'RM5vwxL0MyLlDhtKW_gEmOFzU9MG457CCSltCP9tWkQg3DCt',
#    'summonerName': 'STAIGZOR',
#    'leaguePoints': 642,
#    'rank': 'I',
#    'wins': 138,
#    'losses': 106,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NzrQLHpMeG3M_j7xNINwAA3_rOcGFbTzwO5MHJC4Lg6NjpQQ',
#    'summonerName': 'GachaGom',
#    'leaguePoints': 1372,
#    'rank': 'I',
#    'wins': 201,
#    'losses': 135,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'algoVSh45b58yiovPljyF2EVhS0pU4CkvhVeRUo-h8VvXhw',
#    'summonerName': 'Milk Guy',
#    'leaguePoints': 1191,
#    'rank': 'I',
#    'wins': 206,
#    'losses': 147,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'KQDG47mUa6jkt4Qxe8AsWgT-oZJ3Youpv-vdj2yFp2sd0QA',
#    'summonerName': 'Yiggles',
#    'leaguePoints': 640,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 129,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'xaXnICwQGGZzz8htRHM_G9jAmx1iLSe76ywbzXTCu5Xs_dc',
#    'summonerName': 'Darth Nub',
#    'leaguePoints': 1316,
#    'rank': 'I',
#    'wins': 261,
#    'losses': 177,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'DQdROY8TMepZQsP8ujVdhCzoxHX3g6kbgzJZO3ApsMgi',
#    'summonerName': 'becca tilts',
#    'leaguePoints': 628,
#    'rank': 'I',
#    'wins': 299,
#    'losses': 266,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'UeIXRS3Xf2gmDW9fCcAh51m0Qt8CgnvwCBfofM-recfU8V4',
#    'summonerName': 'flaccidsquid',
#    'leaguePoints': 603,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '55Am61MEXHC4ZRU3_KPpFXQVU6-pEEDsDUPERndj-5AechQ1',
#    'summonerName': 'enchabi',
#    'leaguePoints': 556,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 123,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'EQcO5hvfT_FwB84l_j-PjBCsI9nCIYgW05YUa6LLqTHM3t_U',
#    'summonerName': 'BruisedByGod',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 209,
#    'losses': 198,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '5XBItxgffPPoo4FEXJRm7FfWarHqTVqA1-zTYj9mcm87SY8',
#    'summonerName': 'A monologue D',
#    'leaguePoints': 611,
#    'rank': 'I',
#    'wins': 275,
#    'losses': 242,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'V6ulBfnMkKg4U_UPIt50XKalGpp5z-O7Cmdis0ExXblbgEs7',
#    'summonerName': 'bobbyex',
#    'leaguePoints': 726,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 85,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'e-15XBLvSZmArxQS0F-r5iYj1a-i7QAXcX34EE_AViohMNI73A4wvuA-7Q',
#    'summonerName': 'Wøømy',
#    'leaguePoints': 607,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 49,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'iXCoNyNP-lRUZJH8HVIVpvoJpBES4D5D2-P-BsOClwGJnM0',
#    'summonerName': 'Filup',
#    'leaguePoints': 852,
#    'rank': 'I',
#    'wins': 258,
#    'losses': 220,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0TUh0VWP-ftS0nF2D6npFLRrw7lQoEGEpGIk-M-PDkXlXLWLNLDzwA3g1A',
#    'summonerName': 'AntinomyNA',
#    'leaguePoints': 646,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'YSclOFNmJ95Pug6XBTiU8JKceZkqSrNGeERI_-Y-lyaL',
#    'summonerName': 'TL SaintVicious',
#    'leaguePoints': 956,
#    'rank': 'I',
#    'wins': 385,
#    'losses': 311,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KfDEVb2S8Ne1qz_wDtkGCZBa9HS1_oZDzf8mn2HQt7numsc',
#    'summonerName': 'SouI Reaver',
#    'leaguePoints': 588,
#    'rank': 'I',
#    'wins': 268,
#    'losses': 213,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'kozlKZFE9Ta9zEge5npUkO1128nUKPdUPAOYPsd3cShx3tE',
#    'summonerName': 'SpicyAppies',
#    'leaguePoints': 1013,
#    'rank': 'I',
#    'wins': 254,
#    'losses': 147,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'r0fIwz4-wuzCiFA2TtHDV7HAW1fFLGWJjwF6tj08Go1Fu7g',
#    'summonerName': 'BrownRaft',
#    'leaguePoints': 600,
#    'rank': 'I',
#    'wins': 162,
#    'losses': 140,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'o70JclU3JerEaohFqrPv3i_YouS8FpIgVt9CLZntKvRo7AU',
#    'summonerName': 'Xïąng PönPön',
#    'leaguePoints': 851,
#    'rank': 'I',
#    'wins': 107,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'jpUSHR_Xnokf55GSpYDyDqhzpo7ZwgQUTbuiy5dODH71enc',
#    'summonerName': 'BBEAR DOTA',
#    'leaguePoints': 791,
#    'rank': 'I',
#    'wins': 214,
#    'losses': 180,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mi0bNnHLcw3YY28NXufuOKIVHUfskvm03WdicVTlZ-P-fPx0MMI6zwMl3Q',
#    'summonerName': 'Yami Salami',
#    'leaguePoints': 746,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'VbxpLS3rfDhbmhTWpGqnupG1z1RcbBdfSV6knWKYwOeAV4bg',
#    'summonerName': 'lnuryunshiN',
#    'leaguePoints': 611,
#    'rank': 'I',
#    'wins': 137,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'o7fTPG-5UiJpi_BibT_O6G1VW8dq2Q1ClD31tIYsTd6gtMNYS7N9MUULAA',
#    'summonerName': 'nohoeharry',
#    'leaguePoints': 759,
#    'rank': 'I',
#    'wins': 210,
#    'losses': 178,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'SHB6kZiYv-RaDbzJFfuYj9ZjME83lNODF6H1RZiSrTxTGok',
#    'summonerName': 'SmurfSquatch',
#    'leaguePoints': 661,
#    'rank': 'I',
#    'wins': 244,
#    'losses': 199,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '9MMCSAngG5uVCirJ-E1-iHyxvlVkJDxXCS_n75G94FYfcb0',
#    'summonerName': 'Bebe Level Here',
#    'leaguePoints': 949,
#    'rank': 'I',
#    'wins': 116,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CQU37K85bu9DzFOdab0DKxceO0SeMG5j7ZXUWryD1bcwYFM',
#    'summonerName': 'Xeno',
#    'leaguePoints': 883,
#    'rank': 'I',
#    'wins': 93,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'E0mH4KkIwYOQS_6bIEDgoyErOakSa0dXoFflc28reHC9AlbA',
#    'summonerName': 'uuFaded',
#    'leaguePoints': 586,
#    'rank': 'I',
#    'wins': 162,
#    'losses': 120,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Uaa9dDqPBheU3VxvuWyaJcUQ6dU47-y8yrMHKxxqDUTQFUZu',
#    'summonerName': 'kevyzhou',
#    'leaguePoints': 1086,
#    'rank': 'I',
#    'wins': 459,
#    'losses': 420,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'fXkYXmj3FUwyA54y7wnt-UcmhQk9SZIXo0ar4wM8PwHbgtzJH1-xrkuOBA',
#    'summonerName': 'OCE DICTATOR',
#    'leaguePoints': 1066,
#    'rank': 'I',
#    'wins': 146,
#    'losses': 74,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'z7s3d82_-ZqvWfF002Jrv6ddwYTWzGduuyKN8Mp2HyYKrN0',
#    'summonerName': 'Kaz2',
#    'leaguePoints': 628,
#    'rank': 'I',
#    'wins': 179,
#    'losses': 143,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'MxmvJSm6QPw5dJllC-PAnjIxkVTpGvp7N60c6OsQiU5bQpc',
#    'summonerName': 'NG Poppin',
#    'leaguePoints': 762,
#    'rank': 'I',
#    'wins': 156,
#    'losses': 128,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '0R0mM7Y3i4XMsIRlGpWFMQDUBkBJHWSigE75nQJQyPXWgeQ',
#    'summonerName': 'CHRISTOPHO',
#    'leaguePoints': 671,
#    'rank': 'I',
#    'wins': 201,
#    'losses': 166,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'p96670ox9UbfKUMfJXKWKKjj-thihD-0RLrMPigPI-7P8Bc',
#    'summonerName': 'LunaTunes',
#    'leaguePoints': 525,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '9kG84IvIC19EkB5wSpsy7IoT0QUARzxgjPWkLxXjOz1Yvls',
#    'summonerName': 'Forensics Team',
#    'leaguePoints': 668,
#    'rank': 'I',
#    'wins': 145,
#    'losses': 113,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'IETbTPqJuhcnxbuOOYNEYRoXaxz2neyraGBDKLnV41sZ2TEg',
#    'summonerName': 'soup eater',
#    'leaguePoints': 679,
#    'rank': 'I',
#    'wins': 156,
#    'losses': 127,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'XE0XMCkjkT_VuUVMefOeXFUtgFul-CES5nAIfcpd6lHPKbj6',
#    'summonerName': 'iLoda NA',
#    'leaguePoints': 965,
#    'rank': 'I',
#    'wins': 250,
#    'losses': 175,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '9qzU9s0f1Dr7lCXPGmjgnZIJXDVrOu82Iyco1H-epvof1JIH',
#    'summonerName': 'VX15375231123',
#    'leaguePoints': 1028,
#    'rank': 'I',
#    'wins': 142,
#    'losses': 89,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 's_fDGbb5T94ISGf1bUL82xsE3uq2IkjmH6gABJYlTdwfXI4',
#    'summonerName': 'NG bossoskills',
#    'leaguePoints': 1123,
#    'rank': 'I',
#    'wins': 284,
#    'losses': 239,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '6lSX6gRp2SrPydkvYkQnz9-owbsgsP1djXvDfoE-ihd0HWg',
#    'summonerName': 'ilikeike',
#    'leaguePoints': 1007,
#    'rank': 'I',
#    'wins': 206,
#    'losses': 156,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'zswhebKd9Xh6X2burCGG8kID7cFIc_zddoF0zjM4aU-mQi4',
#    'summonerName': 'Mordenics',
#    'leaguePoints': 822,
#    'rank': 'I',
#    'wins': 176,
#    'losses': 134,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ex6TynHlXdEOTOi6pxIZZHEhgdZp2vfL2NJMqrTi7S_D-eU',
#    'summonerName': 'Mypumpkinbaby',
#    'leaguePoints': 782,
#    'rank': 'I',
#    'wins': 120,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ni1vRd_Q-1YjQFw-50HTaDty-jEgXkp2phgIl70vEFXrxjE',
#    'summonerName': 'Pileofhay',
#    'leaguePoints': 655,
#    'rank': 'I',
#    'wins': 221,
#    'losses': 198,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ZcdAgh9FYGAsImRCmn8tRMmYFRg-kg0yWL6wmY4YGzBSNLs',
#    'summonerName': 'dOGCHAMP',
#    'leaguePoints': 715,
#    'rank': 'I',
#    'wins': 232,
#    'losses': 209,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'FFciSuSCzuCF9t2lstKYjkAJthqXFibVUAXGJz6tW00kpY4',
#    'summonerName': 'urwong',
#    'leaguePoints': 704,
#    'rank': 'I',
#    'wins': 166,
#    'losses': 132,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'td2jopVnHohlCoTwPGTzFdSqKzS2g1BHKYjhDOBm0qBC-flC',
#    'summonerName': 'KinGKraXx',
#    'leaguePoints': 571,
#    'rank': 'I',
#    'wins': 235,
#    'losses': 203,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '9C4FJwQ90h1EplKBkOKMERgJEqff5Lq90lwVRTkbec8xjcw',
#    'summonerName': 'marinethan',
#    'leaguePoints': 616,
#    'rank': 'I',
#    'wins': 169,
#    'losses': 128,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'h7FpeV8a5F_Fq9mNIgG-SwYQbXNQGxAmCuR3g0XLzzo8U4QT3I0j9bnxeA',
#    'summonerName': 'NorthKr Yush',
#    'leaguePoints': 896,
#    'rank': 'I',
#    'wins': 95,
#    'losses': 57,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'nDr0nHCaZmmU_gsSfqmYErhE7CUAiO1padvSRy92O-t8fTRx',
#    'summonerName': 'EpicDøød',
#    'leaguePoints': 617,
#    'rank': 'I',
#    'wins': 148,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '-1uRbC3BdqJ3P3fSEF476cv1JxFbDy0ny-puvAJBY0DJLqc',
#    'summonerName': 'zHydration',
#    'leaguePoints': 753,
#    'rank': 'I',
#    'wins': 233,
#    'losses': 183,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '5GjxFDFudL5Smgoqleeem18S_hbvnyyCbMvzCdEx2PyRpkKZlgJVA-4Jcw',
#    'summonerName': 'annooyin',
#    'leaguePoints': 1014,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 43,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'CXkukzGHODhtpU1LKcxVkpU6LN4dUt5gRNz33A5gHtB-',
#    'summonerName': 'Thien sama',
#    'leaguePoints': 878,
#    'rank': 'I',
#    'wins': 208,
#    'losses': 158,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'JBgHLr6E52nt8n_8fdvafplKPRLImCC4VPBiDAHLM7bKyPs',
#    'summonerName': 'Mister Lau',
#    'leaguePoints': 722,
#    'rank': 'I',
#    'wins': 165,
#    'losses': 136,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '3voIwQal1qBBKHcpfqI4EJRZEw_UTo5LUmIFGt_fV8v_YoZH',
#    'summonerName': 'LanaDelFckingRey',
#    'leaguePoints': 668,
#    'rank': 'I',
#    'wins': 126,
#    'losses': 108,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '-yt2OoibQAvgeQtDL_Q93aBA93473p2uiq8jRk0b5NCt4o0',
#    'summonerName': 'BigJasm',
#    'leaguePoints': 633,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 107,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'P81sL-awTTVzMO74VOpIS7jj67aTHWuPt9CyA26mDjKO0ME',
#    'summonerName': 'Liquid Kurumx',
#    'leaguePoints': 959,
#    'rank': 'I',
#    'wins': 176,
#    'losses': 109,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CJqkCX-bCXPT77FzyB3gZzDSczEWbrNJHqSh0sWreg50aJdpHfkSHuhfng',
#    'summonerName': 'zhiiiouhan',
#    'leaguePoints': 623,
#    'rank': 'I',
#    'wins': 95,
#    'losses': 74,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0XFhBNWke2vwmRqKvCSWwtPqyTx6xe9UNxnOmagIWcMB84Q',
#    'summonerName': 'Sphinx',
#    'leaguePoints': 1011,
#    'rank': 'I',
#    'wins': 283,
#    'losses': 178,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'dMH1ZtRo9Way5VMxnKJrSKzbtHdtgTv2YEdzqkNjamsC0Tw',
#    'summonerName': 'Nightling',
#    'leaguePoints': 1292,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 109,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'q7wyBX2NxIJ1PN_XFyZLojz2B3YbS2m3X0tq-lBSchzISso',
#    'summonerName': 'Shiitaro',
#    'leaguePoints': 479,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 150,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KVLojyH0wtGvAyROOZNQkkNk69xxXTxW0Z-WRdns7s4-7uGoyYx4L2UhVA',
#    'summonerName': 'TwitchSL1CkzNa',
#    'leaguePoints': 463,
#    'rank': 'I',
#    'wins': 108,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'voTcwSFllRLP2EPUlaHIVcB3LHCOGPC_yV0fuKIkTq0nnwI',
#    'summonerName': 'Scytzer',
#    'leaguePoints': 486,
#    'rank': 'I',
#    'wins': 223,
#    'losses': 199,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OEQPJiMqKV7KQncaGilA-aaY0sPQO1L_xwOaVhx0g0BkOFw',
#    'summonerName': 'Strategies',
#    'leaguePoints': 651,
#    'rank': 'I',
#    'wins': 248,
#    'losses': 213,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'wB0PsRTdFQBCQ-edLiiaXfZQj5GDk7IpiC8uqQGtabHi4ng',
#    'summonerName': 'carrotman',
#    'leaguePoints': 598,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'QU0cjkt9go9G46ygF1nWI9lb9PUlcMVYsVso0BJtZxgCFNo',
#    'summonerName': 'Xenophyr',
#    'leaguePoints': 625,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 77,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'x7PJdRh0YSwJM7KLAnVC8S2IX4L0FSrdvx64Q787bHIvvYn5',
#    'summonerName': 'Marcel P',
#    'leaguePoints': 1272,
#    'rank': 'I',
#    'wins': 355,
#    'losses': 231,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'uNjti1HYBX1CQTTqSjq_uGRvDKzd3x9gAcJd3aKeOg-ikgY',
#    'summonerName': 'VX13868730775',
#    'leaguePoints': 1011,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '5-R-YtlIMBHR0Ar8PcFj3ydWl7JDuzobItf-HoNJBhNNNsk',
#    'summonerName': 'sad kings fan',
#    'leaguePoints': 711,
#    'rank': 'I',
#    'wins': 260,
#    'losses': 236,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'kXw3f-Zr_vPCoQ9Uw5gV8TadNoxEP6SpVT4rT7a-7eNrj_c',
#    'summonerName': 'KnightCap',
#    'leaguePoints': 782,
#    'rank': 'I',
#    'wins': 210,
#    'losses': 174,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '7Lh4603QV0o4ArNXUIG4a9ilQeMBCWw6oldM6rh-nX5VP0Y',
#    'summonerName': 'Nep2une',
#    'leaguePoints': 626,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 100,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'yexk-4k69R10IwkXjudWjfx-nyWgREiXKPXwpm6W5pWPGyM',
#    'summonerName': 'Broccóli',
#    'leaguePoints': 826,
#    'rank': 'I',
#    'wins': 172,
#    'losses': 106,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'vslIw45tlj1kbFRtK0obWXosV_Mrzz8Gbv8ev1IZBrLmVC6i',
#    'summonerName': 'WizardTFT',
#    'leaguePoints': 809,
#    'rank': 'I',
#    'wins': 199,
#    'losses': 148,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'kcHwWT5puLEbgN8eXg4BJXoEm9vgJPH1ZYTFoBdjeBXyBK8',
#    'summonerName': 'Chakki',
#    'leaguePoints': 804,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 59,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Qshj0Ev0Kch4ssHpsXd9kfb4_UKei3mwVXgLcoUF6hmu6tk',
#    'summonerName': 'Ultimate Michael',
#    'leaguePoints': 680,
#    'rank': 'I',
#    'wins': 65,
#    'losses': 25,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '9rMwBfpxDFeP2KqvWhH6cmccyE905EJ_vm7v9bmL6BphKxIJlicEue2l9Q',
#    'summonerName': 'luck is skill',
#    'leaguePoints': 672,
#    'rank': 'I',
#    'wins': 179,
#    'losses': 156,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'rYPONBbH7uo83gj4YB7Ltpn0u4fMY6M9HrpHXZCB8ZvCaB0',
#    'summonerName': 'Azl333',
#    'leaguePoints': 813,
#    'rank': 'I',
#    'wins': 307,
#    'losses': 275,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'VAWvJsgIoWbVs7GwIGii0IJtB9FnIG1iNFns5MKDiCzrTx4',
#    'summonerName': 'XTheFarmerX',
#    'leaguePoints': 534,
#    'rank': 'I',
#    'wins': 221,
#    'losses': 194,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'IW_xWvFopgfFhJ-xZgMPmbA5DUpUaXM5-0aBR8SiTGpAp34',
#    'summonerName': 'Dace',
#    'leaguePoints': 1209,
#    'rank': 'I',
#    'wins': 295,
#    'losses': 227,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '9sebSmD2IEfHVv_6O8v_ELmq4Dh79wLo6QpcIxG7G2dgmlu-',
#    'summonerName': 'iCopyKeane',
#    'leaguePoints': 618,
#    'rank': 'I',
#    'wins': 260,
#    'losses': 236,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Mf5fiIPtjO46A6T7yi-bMJGWv9IArn8JxeqWJpyvP0h2u7A',
#    'summonerName': 'Qhost',
#    'leaguePoints': 599,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'epd2kJhhEUSpoZf-Vk0OrQ_d9PWPSolDwA2tgKQ7yWP_WP4',
#    'summonerName': 'casparwu',
#    'leaguePoints': 1400,
#    'rank': 'I',
#    'wins': 295,
#    'losses': 219,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BSAe5UkW1Lu0XEWdpnh5uU1PlTumpG0GODALnFqApRtiqg4',
#    'summonerName': 'CanadaPanda12',
#    'leaguePoints': 939,
#    'rank': 'I',
#    'wins': 210,
#    'losses': 169,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8iUvbVz654MyH03sDq8-i5PQDGIepbacl9HCrc_Lu7Ogtyk',
#    'summonerName': 'Nice Mister Kien',
#    'leaguePoints': 817,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 113,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'QkiWhVJZV4JzmPImTUG-oLJbQr5fQGCm8OYmqmW5hpME8CWp',
#    'summonerName': 'Lëskun',
#    'leaguePoints': 766,
#    'rank': 'I',
#    'wins': 200,
#    'losses': 176,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AAvnInMMMfYRhOS7KpUN-fZQhlb-0GVyUmHkOo_zQtBv7JQ',
#    'summonerName': 'Blueeeeeeeeeee',
#    'leaguePoints': 625,
#    'rank': 'I',
#    'wins': 193,
#    'losses': 176,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'pvN-1glR1drrt7y_0jw2WTYyeAohqsXubd4bMZCJV1J4lI4',
#    'summonerName': 'Starcarity',
#    'leaguePoints': 812,
#    'rank': 'I',
#    'wins': 183,
#    'losses': 147,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OBK6CD7BTARJ27CeoEM2xAs-5lYQW_2SF845rB1Y1xNtsfY',
#    'summonerName': 'OG Fuzi',
#    'leaguePoints': 595,
#    'rank': 'I',
#    'wins': 81,
#    'losses': 41,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '80rR8JXRgA38-LksZGrK2Zff1rFSl6YqTEnCDWrRZnas4BM',
#    'summonerName': 'XII douyu9305388',
#    'leaguePoints': 735,
#    'rank': 'I',
#    'wins': 300,
#    'losses': 270,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ojRXAUotqZK2FgNKqdIwoANwIpYpYuaJdifokXYCX_b-neo',
#    'summonerName': 'MaGaBzzz',
#    'leaguePoints': 682,
#    'rank': 'I',
#    'wins': 151,
#    'losses': 99,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'LACZwzSxeOMu5PQUDoqVXlwUZrtzhAjNSLulXemfHghat4Y',
#    'summonerName': 'm00jo',
#    'leaguePoints': 773,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'V2oymy3HxZSW_RDDt9-DEZnUmutmzOgJcIw8Bpjt35QvOb8',
#    'summonerName': 'DQA',
#    'leaguePoints': 1199,
#    'rank': 'I',
#    'wins': 240,
#    'losses': 165,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'e2DhyWRSZnjDzkxJvLDnnadZx-hGypgpbWGvpv2pdslqbbs',
#    'summonerName': 'Bare Tibbers',
#    'leaguePoints': 600,
#    'rank': 'I',
#    'wins': 111,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '30nay6n_eTg2KaymqxihcAnR1tU4QqqRQ4u-GlieeaYambU',
#    'summonerName': 'Incite',
#    'leaguePoints': 706,
#    'rank': 'I',
#    'wins': 212,
#    'losses': 196,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'jMFao4YMykaVQz94XpPGzJ91929dcdI0PpwO711FdVfjv38',
#    'summonerName': 'humbug',
#    'leaguePoints': 801,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 66,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'd3fX6EgCPBt-aNiZRh8sgNgRJDGDs_gM9qLT5xlcc-wd6yjy',
#    'summonerName': 'IGORblonded',
#    'leaguePoints': 891,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 161,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'wQ5Iu6jZzKeOSedAimwXGCiu67x5aRpjxhOBnLotW9Gywo4',
#    'summonerName': 'jasonjava',
#    'leaguePoints': 1006,
#    'rank': 'I',
#    'wins': 288,
#    'losses': 214,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zaBOXMIXaiOfoo2R9x79biiITxCc3_k6KWTGcdsmFYKKu34',
#    'summonerName': 'milala',
#    'leaguePoints': 685,
#    'rank': 'I',
#    'wins': 229,
#    'losses': 189,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'afPouBVxwrTzLzzDsjFUTx-6Zx2lPV27dZn2QeLuawm71T1I',
#    'summonerName': 'hunterl565',
#    'leaguePoints': 530,
#    'rank': 'I',
#    'wins': 115,
#    'losses': 95,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '2cn41bKpDKP7Bw1vhYvdAst1N7Hbb712b3Gd15STqAfxXqAP',
#    'summonerName': 'Velayy',
#    'leaguePoints': 900,
#    'rank': 'I',
#    'wins': 212,
#    'losses': 168,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TYIcjHgEp8FRizNGgS3btFMRiJSR8c0NolCwbnjUl5s8sHlz',
#    'summonerName': 'Nieroli',
#    'leaguePoints': 573,
#    'rank': 'I',
#    'wins': 80,
#    'losses': 39,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nJGJ0a8-C9A8xqZGkfOrJFtEoLitva7Ok8d6dYsKmL6t_4trFRe2u5nKeg',
#    'summonerName': 'Emperor0ng',
#    'leaguePoints': 932,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '6QAUJec8pu_kAoJmDm8YqzWiHtqArU2jSwcBgJ3geNbgmeE',
#    'summonerName': 'Thats So Frodan',
#    'leaguePoints': 730,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 148,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'eWN30C7b1GRmJNg0cGvuyBlPBjwh85euT00PI5x36jhWsj4zRqlm71bZkQ',
#    'summonerName': 'VVinnie the poop',
#    'leaguePoints': 654,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 127,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'cImRXgUVqbBoWWKwCrFyQddAlFs6ReHWu9o70vEmQNQ5l-I',
#    'summonerName': 'PARTYNEXTDOOR',
#    'leaguePoints': 627,
#    'rank': 'I',
#    'wins': 276,
#    'losses': 256,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'OGk6m3gLkt84TAErs0zkSX2wSA3fQykoFNz2C_W51uSs2SxO',
#    'summonerName': 'ItzYaBoyBeasty',
#    'leaguePoints': 947,
#    'rank': 'I',
#    'wins': 302,
#    'losses': 260,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NHgbeh8Xe1bg6G1CZAktEDj6F9seNDSkyUrGjVRRlxxX5QU6',
#    'summonerName': 'VX xxtouzhu',
#    'leaguePoints': 1008,
#    'rank': 'I',
#    'wins': 254,
#    'losses': 216,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3jzkPks7KvX_GzEI1rqDXLb9na8OYZTgHMqGhMdyZsigdmc',
#    'summonerName': 'BC Socks',
#    'leaguePoints': 1142,
#    'rank': 'I',
#    'wins': 273,
#    'losses': 154,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'yXfE5Z0Rwl7fm0zVbqqI1a3bvQMJ-q4oaK7KoZ0TPaHtbM7h',
#    'summonerName': 'tkamat29',
#    'leaguePoints': 680,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 108,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FHhuGH6_T0mesdSf5J37UvlaR_UjC6BYaOc1-s2j47cbICPC',
#    'summonerName': 'Devil',
#    'leaguePoints': 614,
#    'rank': 'I',
#    'wins': 308,
#    'losses': 282,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'aAKEm6pAsuuDG7XxxrPxWeqxH3LnshrxekVAzhKY54RRnBE',
#    'summonerName': 'Ramblinnn',
#    'leaguePoints': 994,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 95,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0IpNcAjE8O2wA20Wwv1B0znlPmeUGJ4Xs6vO8RT1_6lw-RY',
#    'summonerName': 'ªss',
#    'leaguePoints': 618,
#    'rank': 'I',
#    'wins': 203,
#    'losses': 177,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '4N3utWsZW_k5V1tvHS5avreTLbZyQ9dKXrkI0418-7E6vPtV6jRR9-PgTg',
#    'summonerName': 'AesahTFT',
#    'leaguePoints': 1006,
#    'rank': 'I',
#    'wins': 70,
#    'losses': 27,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'xtj30-lZRwwG0xJCnsaQvGtawjRwkh-blxwcdZl0S7o3Gls',
#    'summonerName': 'qwâd',
#    'leaguePoints': 619,
#    'rank': 'I',
#    'wins': 364,
#    'losses': 357,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'hj3nmNGgVOqR1xOQcZJkafK--kse0yt3iTb0HvxjF5yQ8XQ',
#    'summonerName': 'ASIANGUCCISQUAD',
#    'leaguePoints': 752,
#    'rank': 'I',
#    'wins': 208,
#    'losses': 155,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '46b4qSeyUp2e5y4Eu9YjCIUMZbKvsqgMSacbF4N6DyqSDMU',
#    'summonerName': 'Kiriusaion',
#    'leaguePoints': 835,
#    'rank': 'I',
#    'wins': 200,
#    'losses': 167,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'j46qmivMPDAQqtiumKzu-12-AFCPBaHyO6CWRZw8NEQ9rBZS',
#    'summonerName': 'VanillaXD',
#    'leaguePoints': 807,
#    'rank': 'I',
#    'wins': 237,
#    'losses': 206,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ZcCFKXvBtcxoK4LESatipBINU4thqUjcmCzvwzkWHEHNTzQ',
#    'summonerName': 'Souless',
#    'leaguePoints': 1118,
#    'rank': 'I',
#    'wins': 162,
#    'losses': 88,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'idHppzeCaF-ZBe5aczx1rqQtO79RAKCw3h69FbTY8Yd6cnZc',
#    'summonerName': 'Xellerex',
#    'leaguePoints': 555,
#    'rank': 'I',
#    'wins': 262,
#    'losses': 238,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'nV1_0Fe7s-8HhY0loUUaLLSTZP-hSLhbI9bwJYEoeN57BX34',
#    'summonerName': 'emilyywang',
#    'leaguePoints': 977,
#    'rank': 'I',
#    'wins': 306,
#    'losses': 224,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CtHzV-0bbsRC7xyzfk1SAXr4rhs0S2VrI_S9Fx3k9agaT1U',
#    'summonerName': 'BentoBot',
#    'leaguePoints': 840,
#    'rank': 'I',
#    'wins': 165,
#    'losses': 125,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'QPFrf5WWK_1YYAGuQ-LGnQnvK2dV53_GAK_Tuv3lWyMYD8rs',
#    'summonerName': 'Spethom',
#    'leaguePoints': 768,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 120,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '6270drIDBV3UMDA0CKHq0FViIskQGXuxWrITCOV36YaM6xU',
#    'summonerName': 'Aesah',
#    'leaguePoints': 1468,
#    'rank': 'I',
#    'wins': 204,
#    'losses': 107,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_wDGaSaBRXATaG9-WG_psSxvduBt-bKHU-Mm6TuyIBnp124',
#    'summonerName': 'L0VE D1VE',
#    'leaguePoints': 564,
#    'rank': 'I',
#    'wins': 151,
#    'losses': 109,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KaRZHm3_N6UPZkYg0zazTr4eCT2by3xvIbq9a5sgFg',
#    'summonerName': 'dogdogdog',
#    'leaguePoints': 870,
#    'rank': 'I',
#    'wins': 212,
#    'losses': 194,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NbdRHvvtp7jJchzSDs8Nrw1SnWA4NBXFU4LYTXnkWgEv1P4V',
#    'summonerName': 'wasianiverson',
#    'leaguePoints': 594,
#    'rank': 'I',
#    'wins': 150,
#    'losses': 128,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'TbBasdTgGTWaZnVJtAW8X6aRAa-4CoL6xlS647GFragYxzir',
#    'summonerName': 'the Pr0mised End',
#    'leaguePoints': 604,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'fWYOQM-Ml_a_4Va9rLBAL2aCxmofyiqfCHr_wDPA7pS29tI',
#    'summonerName': 'Pawnup',
#    'leaguePoints': 828,
#    'rank': 'I',
#    'wins': 312,
#    'losses': 263,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'VOIJjjRFcFkRzddIt_4sT86VceygVnE5rDtfTRDosXRi_50',
#    'summonerName': 'YippeeMaokaiYay',
#    'leaguePoints': 899,
#    'rank': 'I',
#    'wins': 174,
#    'losses': 142,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'QDUIjMNyE4YXEzRridHC-civaryrKAX6yXEcJUW7SoSfOKo',
#    'summonerName': 'Stellar Minhee',
#    'leaguePoints': 1204,
#    'rank': 'I',
#    'wins': 180,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Kfm-jIqpWCu-ENzb0RRgK7NEd8SB0t2LXHkFbNzb3_s8ANY',
#    'summonerName': 'cya nerds',
#    'leaguePoints': 851,
#    'rank': 'I',
#    'wins': 261,
#    'losses': 223,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'gE36-8uYxXsW-qn4XcyjtBUbDrmv21FLq7LVvKhSmuMCCVY',
#    'summonerName': 'hmmmmmmmmmmm',
#    'leaguePoints': 621,
#    'rank': 'I',
#    'wins': 121,
#    'losses': 83,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'wxEviARB8ND5qudQnQMRqe2bvP-4x6DiofYOvBWedmOAUDiQ',
#    'summonerName': 'VX F2106138897',
#    'leaguePoints': 880,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 114,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BXBnu4gALJx_BUrO0zZSAlc5zfZ3gL04xRMjjQCInnRvc3A',
#    'summonerName': 'RageRayor',
#    'leaguePoints': 640,
#    'rank': 'I',
#    'wins': 136,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'yyNJnlmLqZgqk_cYqq-g0K8W6jWEma6CB0DQtwRgt9RJKSXYgo_Iw7n2QQ',
#    'summonerName': 'frothy123',
#    'leaguePoints': 704,
#    'rank': 'I',
#    'wins': 166,
#    'losses': 137,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8xeXvrzuAVn78zdbGoFrvLKyanKqNqnHbSpdJLEy_S_TW8o',
#    'summonerName': 'covertsloth',
#    'leaguePoints': 627,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 111,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'T1Sp1mtv5X7g2gjCGYqfRuc5GWHw-Fvent_5Lv30FU9lRrc',
#    'summonerName': 'Soda Is A Cat',
#    'leaguePoints': 650,
#    'rank': 'I',
#    'wins': 50,
#    'losses': 14,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'S8ov85rW_btw3Kwpb0fk2x913dvtgq3Ytb-slmTAnRZ4-jQ',
#    'summonerName': 'TFT BinBin2',
#    'leaguePoints': 728,
#    'rank': 'I',
#    'wins': 166,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'FJNK-U2Si7ln1I1rV97vrXNUkFBppmQvHtVnUz1XGBILspbO',
#    'summonerName': 'zoe only champ',
#    'leaguePoints': 745,
#    'rank': 'I',
#    'wins': 177,
#    'losses': 144,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Pf4w6Ax_qQ3WGYHeZw0LfqEO95yOiJ-IR33gpr3Z2s36Es81',
#    'summonerName': 'C9 k3soju',
#    'leaguePoints': 1463,
#    'rank': 'I',
#    'wins': 468,
#    'losses': 316,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'i2zdZbqI6WwcUED0rrjuBcHFOB1rHFW9bsS2JwtYtyPNquyD',
#    'summonerName': 'JYHOVO',
#    'leaguePoints': 1362,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 131,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'uKRweYFbKoj_oBoJu5OAxq-Sp_rsm-YIV9lRTYtFcxOBLJY',
#    'summonerName': 'Luqun',
#    'leaguePoints': 754,
#    'rank': 'I',
#    'wins': 156,
#    'losses': 130,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'JnKn-Ed66AzLg8-KxHGSOtVH0Yd7QGZT3qholuLBpWnUi5m0hqCqs-3cSQ',
#    'summonerName': 'tyreaal',
#    'leaguePoints': 753,
#    'rank': 'I',
#    'wins': 223,
#    'losses': 189,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'xNvSumNamjj5fqS5JVlbKIKWJq3-9GpRH9lwEoW1275Bk_E',
#    'summonerName': '2 Brain Cell',
#    'leaguePoints': 664,
#    'rank': 'I',
#    'wins': 153,
#    'losses': 117,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'R8toNmGsfMHpPgs4NLmStGLQL1-yD2LyYFjp1QEHXXck4CA',
#    'summonerName': 'onee san lover',
#    'leaguePoints': 731,
#    'rank': 'I',
#    'wins': 244,
#    'losses': 211,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '5UQ83ESJPwrRnppZ1fQMD0WYb-XvxnfChMoFnevVWhiW8dI',
#    'summonerName': 'Noobowl',
#    'leaguePoints': 1008,
#    'rank': 'I',
#    'wins': 166,
#    'losses': 102,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0T9aMZHaPSCxf_36GrKwzqdmv9BdIuVDZakHzzxhoE2F44VR',
#    'summonerName': 'iSexyHugoBabyGOD',
#    'leaguePoints': 1172,
#    'rank': 'I',
#    'wins': 236,
#    'losses': 192,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'J7I_eamvYRg0-UgXbqEN6shEmSu6PKRxDKpDIaVExeobuRA',
#    'summonerName': 'garet',
#    'leaguePoints': 1328,
#    'rank': 'I',
#    'wins': 247,
#    'losses': 132,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'GCcqGDgUNtit9CP5Dck_e21MdYAod5LlGYhZ-jKp-7c0704',
#    'summonerName': 'Cheney',
#    'leaguePoints': 722,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'DmOi-fSJ_ifvBPQM4cdZMZC6JOZMOPXpEdzPrlfrI-p5eoKhDFdYd4t31g',
#    'summonerName': 'TTV BrosephTFT',
#    'leaguePoints': 831,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Q_JgEcoy6NlD34N-zVozQfzGo5ebKUVf13kvqOQT60vN5CZ0',
#    'summonerName': 'PhoenixLXIX',
#    'leaguePoints': 532,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 77,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '6twnnz-c3dS_djIMt5PPt2t8yYTRTkU1S1eF5TCvopJR3rwq',
#    'summonerName': 'Conzie',
#    'leaguePoints': 631,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KNKN2wzB3cU7_RZjB509uzL_nVeoQUxqZjMdi8EmovlwJ0Y',
#    'summonerName': 'sponcyy',
#    'leaguePoints': 841,
#    'rank': 'I',
#    'wins': 184,
#    'losses': 158,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ZevDuZuwmF53Roea4UM7Pc4-6IB3NQB-cS6aSa-zkrIqwkQ',
#    'summonerName': 'Saibur',
#    'leaguePoints': 624,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 150,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'RXtXoR7v0Ej8zacJO-ecEsKnGtUef1FkxBUOcUFh1HYyw8D6HWMBmiDJpg',
#    'summonerName': 'moseliuli',
#    'leaguePoints': 719,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'qjB1i2FagzpXJXJnhfC8oLXw4hwRK8gyczJSR0LqrCwIO9e6',
#    'summonerName': 'OatmealWater',
#    'leaguePoints': 844,
#    'rank': 'I',
#    'wins': 264,
#    'losses': 199,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '83li9zcQbL2_u12TwkkQiuxllgGDJajuBOZdal5EEoM8UHk',
#    'summonerName': 'Subzeroark',
#    'leaguePoints': 513,
#    'rank': 'I',
#    'wins': 120,
#    'losses': 96,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '4GiQTXQhJrfBNzrm-RV_rCZXH-e3u4jqozyUrofGF1hlgwo',
#    'summonerName': 'FingerLicker',
#    'leaguePoints': 1243,
#    'rank': 'I',
#    'wins': 241,
#    'losses': 154,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'iQKL9yb-JmrSdiHsrMEK7xj_5YZhE70uwNp84n3g6kbTh48',
#    'summonerName': 'BrosephTFT',
#    'leaguePoints': 683,
#    'rank': 'I',
#    'wins': 117,
#    'losses': 80,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
# ...
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nikjNNnjc7krMbC1bSJ6iX6r6SBFQEPWDAgVaITm4HEy2QY',
#    'summonerName': 'Old Lodo',
#    'leaguePoints': 964,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 125,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'D27DbJ5Wa4lzU3eJ-plKYzgoJqHPUk1pa5yUlBP1_yJLQMs',
#    'summonerName': 'FreshVeggies',
#    'leaguePoints': 610,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 124,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'bitiNRGGjvoPaXOhl-NGPpgi8hgo3y_Iz0ZiFKWc9s2-8N5F',
#    'summonerName': 'TSM FTX Souless',
#    'leaguePoints': 1123,
#    'rank': 'I',
#    'wins': 146,
#    'losses': 65,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '4sQ6Is7KVOdKnSDT3OqeXGd-gKDUEFUe70-Ag8bkk1eVwII',
#    'summonerName': 'zzz Rain',
#    'leaguePoints': 637,
#    'rank': 'I',
#    'wins': 150,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'gMqlV8ckGLyiOYFJcPY_7Kk6BsvZd2cDbiAJkv4ZTkn0M80',
#    'summonerName': 'BIGsunnyDEE',
#    'leaguePoints': 987,
#    'rank': 'I',
#    'wins': 247,
#    'losses': 187,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'vNpGFYJRlV5bZNlv4PWBdUEic8tyUesmI6mj2zSiW-Rq9Zg',
#    'summonerName': 'saintOswald',
#    'leaguePoints': 694,
#    'rank': 'I',
#    'wins': 92,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'WW_yj0Jv9uisdmrGbcnTFp6Nf0YlUNhhifjC3LknYiAWQYE',
#    'summonerName': 'TTV GGBrick ',
#    'leaguePoints': 579,
#    'rank': 'I',
#    'wins': 254,
#    'losses': 221,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7EbRl4DQiT9h_a8-fyqP_4_x38wpmb1x0oq7NgztMv07v2rQ',
#    'summonerName': 'inikoiniko',
#    'leaguePoints': 1428,
#    'rank': 'I',
#    'wins': 228,
#    'losses': 133,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'C5b037T_VQ4PbSeJNHGKRVhOxEgqk__aTxYprW9_7EV56wY',
#    'summonerName': 'eviljordan',
#    'leaguePoints': 962,
#    'rank': 'I',
#    'wins': 121,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0ggqPe5g8ncHE04Mkan8aJzGXnNeFW0f61qOU97OedvCjZY',
#    'summonerName': 'Teem Onodera',
#    'leaguePoints': 910,
#    'rank': 'I',
#    'wins': 175,
#    'losses': 126,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oaj-op4zzRExgrtJifUQL8mx4P3jwLRAbVlUh7LvolnVh36NJx3QnrYexQ',
#    'summonerName': 'Elaborate Rabbit',
#    'leaguePoints': 751,
#    'rank': 'I',
#    'wins': 158,
#    'losses': 110,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'NR3_l7jLkDjnRsYa3q_LAY4zTzFYCMDj263UD38ux4-8mXU',
#    'summonerName': 'Mobalytics Ace',
#    'leaguePoints': 960,
#    'rank': 'I',
#    'wins': 207,
#    'losses': 149,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'cHD0I7wTaby5-7NjBQSkre16UaAiCEPog3EuAwUtMnwB0po',
#    'summonerName': 'trywe',
#    'leaguePoints': 508,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 145,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'fbROrKw2R3_B1Ydk0E-O6XDTYQ9kEShPAH7Re-cahNqHecw',
#    'summonerName': 'bertasaurus',
#    'leaguePoints': 1634,
#    'rank': 'I',
#    'wins': 286,
#    'losses': 161,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'vH7SNUm_yAufTuLJnOo-hpxH8DVbm4hL5Uyw_8YlFVSpzUzP',
#    'summonerName': 'forsen smurf acc',
#    'leaguePoints': 848,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 98,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'lirmm8vmQRiyqUe7cWgnGCPBduuOolGhwyetiLGtkfovLZk',
#    'summonerName': 'SpencerTFT',
#    'leaguePoints': 1326,
#    'rank': 'I',
#    'wins': 207,
#    'losses': 124,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'R_iXLLwSlFBUrLrBTkmHjA_xnmP33sISjD4VBQMbE1ux8MZ2',
#    'summonerName': 'Davidas',
#    'leaguePoints': 632,
#    'rank': 'I',
#    'wins': 72,
#    'losses': 31,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '22IoudWyzHSz4iyTHKPlWq2LU0-Y2v8jJxenFaWStCcDe90',
#    'summonerName': 'devlus',
#    'leaguePoints': 689,
#    'rank': 'I',
#    'wins': 236,
#    'losses': 187,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'deSoi9E5St432AZRCHNFFg0rlhp5TsOUwh_smXYx-KoAPrE',
#    'summonerName': 'Phoenixaa',
#    'leaguePoints': 675,
#    'rank': 'I',
#    'wins': 148,
#    'losses': 120,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'OW9GKfBwJDf1zhM6w22ccbq0Q17N-E_4uFvd3e5WHvHEsP0',
#    'summonerName': 'Xiao Mei Bi',
#    'leaguePoints': 581,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 163,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '_p63Oxzs-PShvAK1rfPPuTUWegZZbo8BxXyFCfRO8j2ZCKY',
#    'summonerName': 'Hakspo',
#    'leaguePoints': 779,
#    'rank': 'I',
#    'wins': 239,
#    'losses': 208,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2nExLmSefYb6cWencNKi9iHFyceaynkVNzDGyYcmeQWWXh4',
#    'summonerName': 'Rainplosion',
#    'leaguePoints': 1205,
#    'rank': 'I',
#    'wins': 263,
#    'losses': 176,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KEt-3D3uCyJTlr7i3pele9YYsC8CABAPTlGwYmxkJtokhcU',
#    'summonerName': 'enaek',
#    'leaguePoints': 799,
#    'rank': 'I',
#    'wins': 146,
#    'losses': 103,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '93rqFrmVpeVGDHIlpECv2eyAdi4JuOPA87DkJ0saczxs9AA',
#    'summonerName': 'Sehnbon',
#    'leaguePoints': 877,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3i67Wj3LEQpsV6T0kbqHskK0ebXvVTCUa6HM4mCT6qJz1-8',
#    'summonerName': 'deeekayy',
#    'leaguePoints': 705,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 95,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'jQ21bcj5sS3TnIwrIz44CuJIjm-VssFiQ_CH8uyOgL1bB1E',
#    'summonerName': 'Harukawa Maki',
#    'leaguePoints': 755,
#    'rank': 'I',
#    'wins': 137,
#    'losses': 100,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'jaLpC1cG3A_rFWbb0nxBpQ6KFRMRS2AR6CPkHcVB7x3HiRiQfiesWMBzVA',
#    'summonerName': 'TTV EMlTWOHS',
#    'leaguePoints': 814,
#    'rank': 'I',
#    'wins': 225,
#    'losses': 191,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FspbWnneghxlxG-NTqlG1a1P4w4wMMRJUZf63Y-qmpiTXhQ',
#    'summonerName': 'GGitsRyan',
#    'leaguePoints': 943,
#    'rank': 'I',
#    'wins': 158,
#    'losses': 116,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'nLc8x8z6GSrViSE6ahkaSue-poaTtvYGy5BG1LCpCIXGD1A',
#    'summonerName': 'ChungMoney12',
#    'leaguePoints': 746,
#    'rank': 'I',
#    'wins': 158,
#    'losses': 100,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'kOAL-oqfDNH8dl7HhVuSzaPtQIw5_znY7Yfajq682UboZgM',
#    'summonerName': 'TORONTOTOKYO',
#    'leaguePoints': 652,
#    'rank': 'I',
#    'wins': 309,
#    'losses': 284,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'VHNRLsFloCnhqsLUrI49KDhHc_WVwuPDCluL0EbCaFVYpZnptAxZ4_O6JQ',
#    'summonerName': 'VOIDS1N',
#    'leaguePoints': 932,
#    'rank': 'I',
#    'wins': 238,
#    'losses': 182,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'w8DEc9g9iO6uhhErG4dXfTZkBKdm7WRyQILjJRfXoOZ0IFUx',
#    'summonerName': 'Kaíro',
#    'leaguePoints': 1060,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 141,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'v0_EScViZSfOkqc9czzsKsdNuT161M3VZlOf0b26Nid9zXlP',
#    'summonerName': 'Dıshsoap',
#    'leaguePoints': 1533,
#    'rank': 'I',
#    'wins': 309,
#    'losses': 158,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'G8pOS2sYl-lrj-UwnoUtb3ex9zN0c9F9AmwKSXUsyuGMR9s',
#    'summonerName': '109dream',
#    'leaguePoints': 775,
#    'rank': 'I',
#    'wins': 211,
#    'losses': 154,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'lGvkSm5k971zwBGIl2305OY-tLpzOJoUP-nZsQmZFZ__srQ',
#    'summonerName': 'esportslaw',
#    'leaguePoints': 803,
#    'rank': 'I',
#    'wins': 115,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'uKFSo5e5i6PTDmyOvIMXWJ7h1Qwxf1xnjnqv1L53Ieopy6g',
#    'summonerName': 'A Common Quail',
#    'leaguePoints': 713,
#    'rank': 'I',
#    'wins': 209,
#    'losses': 198,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ARTJM4l_kkJFot_7L0ZaXsWsjuqzDwfFtqbkUxrZ8pCv4Kyx',
#    'summonerName': 'Dry Biz',
#    'leaguePoints': 710,
#    'rank': 'I',
#    'wins': 88,
#    'losses': 58,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'xb5wfoIednVtXk5_M5bUzO5noz7W4msLSJoorOmzAGb9nLo',
#    'summonerName': 'ajmonsta',
#    'leaguePoints': 1018,
#    'rank': 'I',
#    'wins': 205,
#    'losses': 162,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'djON2CSggupSVHWBs22vgFkJyLg2_lzOwgck4t_tvvPOyv_B',
#    'summonerName': 'xiao dian dian',
#    'leaguePoints': 771,
#    'rank': 'I',
#    'wins': 244,
#    'losses': 199,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '0i8NlWcgOmCkqeBJXnSGBrcT8QHpZFHaD7IEMPrMdOexIxM',
#    'summonerName': 'Gott3m',
#    'leaguePoints': 593,
#    'rank': 'I',
#    'wins': 177,
#    'losses': 144,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KMW9F2_SHqLggLp82gcn-tYg_MXs8iB-cYTqRQB-V5GecGk',
#    'summonerName': 'Helping',
#    'leaguePoints': 691,
#    'rank': 'I',
#    'wins': 120,
#    'losses': 102,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'hr_gfNVaEbBEqvCNr3eDeTBxQRK0Owjy1AuHIxb7yyISASU',
#    'summonerName': 'ReynzeR',
#    'leaguePoints': 860,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 99,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'cuOOQUbhA2PQbAzdqzRUPQKpkODXSZ-DoeabLTkY5sj2KY0',
#    'summonerName': 'Clear',
#    'leaguePoints': 1305,
#    'rank': 'I',
#    'wins': 188,
#    'losses': 124,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'NCjBi4mcKOLECAxsepRRYVk-fgiDyc8pz1e9fcplixwHPCg',
#    'summonerName': 'My Hopend',
#    'leaguePoints': 697,
#    'rank': 'I',
#    'wins': 198,
#    'losses': 172,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'kLkmPELW8ABkMIeJ6iIG6nQNlvvLyfycq4bpJYFVp4BAz0T6',
#    'summonerName': 'Nostereleven',
#    'leaguePoints': 826,
#    'rank': 'I',
#    'wins': 276,
#    'losses': 222,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Mz3lv0svb59lwtWLGdRQ98DeUCcxmmb6IONdC6uPI4_vKqs',
#    'summonerName': 'ItsDinodan',
#    'leaguePoints': 601,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'zI7kg707sQbzUF6xsNRFXRXqaBSlT7aGpn8WRGC0xjBBnNTu',
#    'summonerName': 'rayditz',
#    'leaguePoints': 851,
#    'rank': 'I',
#    'wins': 197,
#    'losses': 159,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'EtpBiF7dKXMk0er9CC1HP3u9r8yzkfTbsszoKuhDeEjTNWFa',
#    'summonerName': 'LIMIT TEST',
#    'leaguePoints': 663,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 53,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'D1mLEF_dgCO0W3dPG589rcq6cpCV8jCrmRKt3uNeCgYXfR5Q9MRZVWqgdw',
#    'summonerName': 'click my d',
#    'leaguePoints': 1212,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 128,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'o-bNc7Qyb86ydC8fL1nQtQALU7L1LAUh7K_oV3e846kFaAI',
#    'summonerName': 'iiLucky',
#    'leaguePoints': 1176,
#    'rank': 'I',
#    'wins': 281,
#    'losses': 190,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3kvJYDHM5stEv0mpa_JnwsZ0w2Jqqg2zm1vvSFaL834_a8-8',
#    'summonerName': 'BlakeAustin',
#    'leaguePoints': 568,
#    'rank': 'I',
#    'wins': 180,
#    'losses': 130,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'kO5OL7vp5b3KpZSUOLNL3Uoqms-CyVDHMWM7jjawTbxnu0eS',
#    'summonerName': 'shiloof',
#    'leaguePoints': 923,
#    'rank': 'I',
#    'wins': 165,
#    'losses': 127,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Xn3PXqUXJJz86CkdJ2vDFIePMUPTYZuqQuPsMk-Q6REuPig',
#    'summonerName': 'EndofSky',
#    'leaguePoints': 777,
#    'rank': 'I',
#    'wins': 313,
#    'losses': 301,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'hDkE1npzcSYhE12H7B0iDR4D3jfceu7Vgrr_Fi4bbYc_KaSw',
#    'summonerName': 'Riot imowt',
#    'leaguePoints': 792,
#    'rank': 'I',
#    'wins': 185,
#    'losses': 146,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'kAd6QzmcpfURUyxwahwvPOAfDmxNCYflqFyaPe725D1ewow',
#    'summonerName': 'QualityHooker',
#    'leaguePoints': 897,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '4uNV4VGi_tCd4jXxVX5EGTca9dbtXYUNZkF_GYG29TBfsCs',
#    'summonerName': 'guubums',
#    'leaguePoints': 1156,
#    'rank': 'I',
#    'wins': 213,
#    'losses': 131,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2r6Qz4fRzyKZSVj-fR9W8c5YXVs52qPVSXnOQIBm-Fte9VU',
#    'summonerName': 'Somber Somber',
#    'leaguePoints': 602,
#    'rank': 'I',
#    'wins': 317,
#    'losses': 277,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'v-BLFQFwKodIHWvtqJewXc5cQyeb43rkctm0PzgzAFzsRMQ',
#    'summonerName': 'TempestLife',
#    'leaguePoints': 724,
#    'rank': 'I',
#    'wins': 124,
#    'losses': 87,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8Kv9W5cWr_y2ptCx7KhsEm6PC7zDwhRHe-Y4Vr04j3S3F-g',
#    'summonerName': 'Liquid Goose',
#    'leaguePoints': 909,
#    'rank': 'I',
#    'wins': 247,
#    'losses': 178,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Hx7emBO_nrednpSToAmxmoTwVPKU-eP5fNZIXmShBPr1T4s',
#    'summonerName': 'daCableguy',
#    'leaguePoints': 644,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 112,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True}]}
